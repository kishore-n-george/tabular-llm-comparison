# %% [markdown]
# # Extended Error Analysis for TabICL and TabPFN
#
# This notebook extends the error analysis from the comprehensive comparison to include detailed analysis of TabICL and TabPFN models. It builds upon the comprehensive comparison notebook and assumes the following variables are available:
#
# - **Models**: `models` dictionary containing XGBoost, TabPFN v2, and TabICL
# - **Data**: `X_train_scaled`, `X_test_scaled`, `y_train`, `y_test`
# - **Features**: `feature_names` list
#
# ## Analysis Components:
# 1. **Cross-Model Error Comparison**: Compare error patterns across all models
# 2. **Model-Specific Error Analysis**: Deep dive into TabICL and TabPFN errors
# 3. **Confidence Analysis**: Prediction confidence comparison
# 4. **Feature-based Error Analysis**: Which features cause errors in each model
# 5. **Error Overlap Analysis**: Common vs unique errors across models
# 6. **Uncertainty Quantification**: Model uncertainty in predictions

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_recall_fscore_support, roc_curve, auc
import warnings
warnings.filterwarnings('ignore')
# Memory management utilities
import gc
import pickle
import os
import torch

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("📊 Extended Error Analysis Framework Loaded")
print("Ready to analyze TabICL and TabPFN error patterns")

from dry_bean_extended_error_analysis import run_dry_bean_error_analysis
analyzer = run_dry_bean_error_analysis('dry_bean_section2_results.pkl')
# Out:
# 📊 Extended Error Analysis Framework Loaded
# Ready to analyze TabICL and TabPFN error patterns
# 📊 Dry Bean Extended Error Analysis Framework Initialized
# Ready to analyze model error patterns
# ✅ Section 2 results loaded successfully!
# Models available: ['XGBoost', 'TabPFN v2', 'TabICL', 'FT-Transformer']
# Features: 16
# Classes: 7
# Test samples: 2,723
#
# 📋 Feature Names:
#     1. Area
#     2. Perimeter
#     3. MajorAxisLength
#     4. MinorAxisLength
#     5. AspectRatio
#     6. Eccentricity
#     7. ConvexArea
#     8. EquivDiameter
#     9. Extent
#    10. Solidity
#    ... and 6 more features
# 🚀 STARTING COMPLETE DRY BEAN ERROR ANALYSIS
# ================================================================================
# 🔮 Generating predictions from all models...
#    Processing XGBoost...
#      Misclassified: 216 / 2723 (7.93%)
#    Processing TabPFN v2...
#      Misclassified: 192 / 2723 (7.05%)
#    Processing TabICL...
#      Misclassified: 191 / 2723 (7.01%)
#    Processing FT-Transformer...
#      Misclassified: 204 / 2723 (7.49%)
#
# ✅ Predictions generated for all models
# 📊 CROSS-MODEL ERROR COMPARISON
# ================================================================================
#          Model  Total_Errors  Error_Rate_%  Accuracy  Precision_Weighted  Recall_Weighted  F1_Weighted  Precision_Macro  Recall_Macro  F1_Macro  Precision_Std  Recall_Std  F1_Std
#        XGBoost           216        7.9324    0.9207              0.9209           0.9207       0.9207           0.9358        0.9314    0.9335         0.0417      0.0426  0.0414
#      TabPFN v2           192        7.0510    0.9295              0.9295           0.9295       0.9294           0.9420        0.9392    0.9404         0.0346      0.0412  0.0362
#         TabICL           191        7.0143    0.9299              0.9297           0.9299       0.9297           0.9418        0.9399    0.9408         0.0335      0.0399  0.0359
# FT-Transformer           204        7.4917    0.9251              0.9260           0.9251       0.9253           0.9406        0.9341    0.9371         0.0442      0.0371  0.0387
#
# 💾 Results saved to 'dry_bean_cross_model_error_comparison.csv'
# 🎯 CONFIDENCE ANALYSIS
# ============================================================
#
# XGBoost Confidence Analysis:
#    Average confidence (correct): 0.9725
#    Average confidence (misclassified): 0.7818
#    Low confidence errors (<60%): 19.9%
#    High confidence errors (>80%): 51.9%
#
# TabPFN v2 Confidence Analysis:
#    Average confidence (correct): 0.9533
#    Average confidence (misclassified): 0.7322
#    Low confidence errors (<60%): 24.5%
#    High confidence errors (>80%): 35.4%
#
# TabICL Confidence Analysis:
#    Average confidence (correct): 0.9555
#    Average confidence (misclassified): 0.7402
#    Low confidence errors (<60%): 22.5%
#    High confidence errors (>80%): 36.6%
#
# FT-Transformer Confidence Analysis:
#    Average confidence (correct): 0.9491
#    Average confidence (misclassified): 0.7302
#    Low confidence errors (<60%): 26.0%
#    High confidence errors (>80%): 39.2%
# 📊 CONFIDENCE STATISTICS
#          Model  Avg_Confidence_Correct  Avg_Confidence_Misclassified  Std_Confidence_Correct  Std_Confidence_Misclassified  Low_Confidence_Errors_%  High_Confidence_Errors_%
#        XGBoost                  0.9725                        0.7818                  0.0771                        0.1640                  19.9074                   51.8519
#      TabPFN v2                  0.9533                        0.7322                  0.1001                        0.1591                  24.4792                   35.4167
#         TabICL                  0.9555                        0.7402                  0.0984                        0.1540                  22.5131                   36.6492
# FT-Transformer                  0.9491                        0.7302                  0.1024                        0.1659                  25.9804                   39.2157
# 🔍 FEATURE-BASED ERROR ANALYSIS
# ============================================================
#
# Analyzing XGBoost...
#    Top 5 significant features (p < 0.05):
#      1. ConvexArea: diff=-0.2665, p=0.0002
#      2. Area: diff=-0.2664, p=0.0002
#      3. Perimeter: diff=-0.2531, p=0.0004
#      4. MajorAxisLength: diff=-0.2455, p=0.0006
#      5. EquivDiameter: diff=-0.2405, p=0.0007
#
# Analyzing TabPFN v2...
#    Top 5 significant features (p < 0.05):
#      1. ConvexArea: diff=-0.2674, p=0.0004
#      2. Area: diff=-0.2664, p=0.0004
#      3. Perimeter: diff=-0.2561, p=0.0006
#      4. MajorAxisLength: diff=-0.2448, p=0.0011
#      5. EquivDiameter: diff=-0.2426, p=0.0012
#
# Analyzing TabICL...
#    Top 5 significant features (p < 0.05):
#      1. ConvexArea: diff=-0.2611, p=0.0005
#      2. Area: diff=-0.2601, p=0.0005
#      3. Perimeter: diff=-0.2498, p=0.0009
#      4. MajorAxisLength: diff=-0.2410, p=0.0014
#      5. EquivDiameter: diff=-0.2363, p=0.0016
#
# Analyzing FT-Transformer...
#    Top 5 significant features (p < 0.05):
#      1. ConvexArea: diff=-0.2551, p=0.0005
#      2. Area: diff=-0.2549, p=0.0005
#      3. Perimeter: diff=-0.2410, p=0.0009
#      4. MajorAxisLength: diff=-0.2387, p=0.0011
#      5. EquivDiameter: diff=-0.2286, p=0.0017
# 🔄 ERROR OVERLAP ANALYSIS
# ============================================================
#
# Error Overlap Statistics:
#    Common errors (all models): 152
#    XGBoost unique errors: 29
#    TabPFN v2 unique errors: 3
#    TabICL unique errors: 4
#    FT-Transformer unique errors: 15
#
# Pairwise Error Overlaps:
#    XGBoost_vs_TabPFN v2: 169
#    XGBoost_vs_TabICL: 167
#    XGBoost_vs_FT-Transformer: 172
#    TabPFN v2_vs_TabICL: 179
#    TabPFN v2_vs_FT-Transformer: 170
#    TabICL_vs_FT-Transformer: 172
# 🔍 MODEL-SPECIFIC ERROR INSIGHTS
# ================================================================================
#
# 📊 XGBOOST ERROR ANALYSIS
# ------------------------------------------------------------
# Total Errors: 216 (7.93%)
# Unique Errors: 29 (13.4% of model errors)
# Average Confidence (Correct): 0.973
# Average Confidence (Errors): 0.782
# Low Confidence Errors: 19.9%
# High Confidence Errors: 51.9%
# Significant Feature Differences: 6/16
# Top 3 Problematic Features:
#   1. ConvexArea: -0.2665
#   2. Area: -0.2664
#   3. Perimeter: -0.2531
#   🌳 XGBoost-Specific Insights:
#   - Tree-based errors often indicate feature interaction issues
#   - Consider feature engineering or hyperparameter tuning
#   - May benefit from ensemble methods
#   - Check for overfitting if validation performance differs significantly
#   ✅ Good performance - minor optimizations needed
#
# 📊 TABPFN V2 ERROR ANALYSIS
# ------------------------------------------------------------
# Total Errors: 192 (7.05%)
# Unique Errors: 3 (1.6% of model errors)
# Average Confidence (Correct): 0.953
# Average Confidence (Errors): 0.732
# Low Confidence Errors: 24.5%
# High Confidence Errors: 35.4%
# Significant Feature Differences: 7/16
# Top 3 Problematic Features:
#   1. ConvexArea: -0.2674
#   2. Area: -0.2664
#   3. Perimeter: -0.2561
#   🧠 TabPFN-Specific Insights:
#   - Prior-based predictions may struggle with out-of-distribution samples
#   - Consider context size optimization for better performance
#   - Errors may indicate dataset shift from pretraining distribution
#   - TabPFN works best with datasets similar to its training distribution
#   ✅ Good performance - minor optimizations needed
#
# 📊 TABICL ERROR ANALYSIS
# ------------------------------------------------------------
# Total Errors: 191 (7.01%)
# Unique Errors: 4 (2.1% of model errors)
# Average Confidence (Correct): 0.956
# Average Confidence (Errors): 0.740
# Low Confidence Errors: 22.5%
# High Confidence Errors: 36.6%
# Significant Feature Differences: 7/16
# Top 3 Problematic Features:
#   1. ConvexArea: -0.2611
#   2. Area: -0.2601
#   3. Perimeter: -0.2498
#   🎯 TabICL-Specific Insights:
#   - In-context learning errors may indicate poor example selection
#   - Consider diverse example selection strategies
#   - Context window utilization may need optimization
#   - Performance depends heavily on the quality of in-context examples
#   ✅ Good performance - minor optimizations needed
#
# 📊 FT-TRANSFORMER ERROR ANALYSIS
# ------------------------------------------------------------
# Total Errors: 204 (7.49%)
# Unique Errors: 15 (7.4% of model errors)
# Average Confidence (Correct): 0.949
# Average Confidence (Errors): 0.730
# Low Confidence Errors: 26.0%
# High Confidence Errors: 39.2%
# Significant Feature Differences: 6/16
# Top 3 Problematic Features:
#   1. ConvexArea: -0.2551
#   2. Area: -0.2549
#   3. Perimeter: -0.2410
#   🤖 FT-Transformer-Specific Insights:
#   - Attention-based errors may indicate complex feature interactions
#   - Consider adjusting model depth or attention heads
#   - May need more training data or regularization
#   - Feature tokenization strategy could be optimized
#   ✅ Good performance - minor optimizations needed
# 📋 COMPREHENSIVE ERROR ANALYSIS SUMMARY
# ================================================================================
#
# 🏆 PERFORMANCE RANKING (by error rate):
#    1. TabICL: 7.01% error rate
#    2. TabPFN v2: 7.05% error rate
#    3. FT-Transformer: 7.49% error rate
#    4. XGBoost: 7.93% error rate
#
# 🔍 KEY FINDINGS:
#    • Best performing model: TabICL (7.01% error rate)
#    • Worst performing model: XGBoost (7.93% error rate)
#    • Common errors across all models: 152 samples
#    • Most unique errors: XGBoost
#    • Most confident model: XGBoost (0.973 avg confidence)
#
# 💡 RECOMMENDATIONS:
#
# 1. Model Selection:
#    • For production: TabICL (lowest error rate)
#    • For reliability: XGBoost (most consistent confidence)
#
# 2. Error Reduction Strategies:
#    • XGBoost: Focus on 29 unique error cases
#      - Address 6 problematic features
#    • TabPFN v2: Focus on 3 unique error cases
#      - Address 7 problematic features
#    • TabICL: Focus on 4 unique error cases
#      - Address 7 problematic features
#    • FT-Transformer: Focus on 15 unique error cases
#      - Address 6 problematic features
#
# 3. Ensemble Opportunities:
#    • Models show complementary errors (only 152 common errors)
#    • Consider ensemble methods to leverage model diversity
#    • Weighted voting based on confidence scores could improve performance
#
# 4. Data Quality Improvements:
#    • Investigate 152 samples misclassified by all models
#    • These may indicate data quality issues or inherently difficult cases
#    • Consider data cleaning or feature engineering for these samples
#
# 5. Model-Specific Improvements:
#    • XGBoost: Feature engineering and hyperparameter optimization
#    • TabPFN v2: Optimize context size and check for distribution shift
#    • TabICL: Improve example selection and context utilization
#    • FT-Transformer: Adjust architecture or training strategy
#
# ✅ Error analysis complete! Use these insights to improve model performance.
# 💾 Saving analysis results to 'dry_bean_error_analysis_results/'...
# ✅ Analysis results saved to 'dry_bean_error_analysis_results/'
#
# 🎉 COMPLETE ERROR ANALYSIS FINISHED!
# Check the generated plots and CSV files for detailed results.
