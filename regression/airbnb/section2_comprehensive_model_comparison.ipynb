# %% [markdown]
# # Comprehensive Model Comparison for Airbnb Regression
#
# This notebook provides a comprehensive comparison of all trained models for Airbnb price prediction using enhanced data:
#
# ## Models Compared
#
# 1. **XGBoost Enhanced** - Enhanced preprocessing with optimized hyperparameters
# 2. **FT-Transformer Enhanced** - Improved version with enhanced data and target scaling
# 3. **SAINT Enhanced** - Self-Attention and Intersample Attention Transformer with enhanced data
#
# ## Analysis Includes
#
# - Performance metrics comparison (R², RMSE, MAE, MAPE)
# - Training and inference time analysis
# - Feature importance comparison
# - Comprehensive visualizations
# - Business recommendations
#
# ## Key Features of Enhanced Data
#
# - **Outlier Removal**: Using Isolation Forest
# - **Feature Engineering**: Polynomial, interaction, and binned features
# - **Advanced Scaling**: RobustScaler for better outlier handling
# - **Feature Selection**: Top features via mutual information
# - **Target Transformation**: Optimal transformation for better model performance

# %% [markdown]
# ## 1. Setup and Imports

# %%
# Run the comprehensive model comparison
exec(open('section2_all_models_comparison.py').read())
# Out:
# 2025-07-31 11:37:52,278 - INFO - Starting comprehensive model comparison for Airbnb dataset
# 2025-07-31 11:37:52,290 - INFO - Enhanced data loaded: 9777 test samples, 43 features
# 🏠 COMPREHENSIVE MODEL COMPARISON FOR AIRBNB REGRESSION
# ...
# 📊 Loading enhanced data...
# ✅ Enhanced data loaded successfully!
#    Test samples: 9,777
#    Features: 43 (after feature engineering & selection)
#    Target transformation: boxcox
#    Outliers removed: 2263
#
# 🖥️ Using device: cuda
# 2025-07-31 11:37:52,503 - INFO - Using device: cuda
# 📦 Loading Enhanced XGBoost model...
# 2025-07-31 11:37:52,730 - INFO - XGBoost Enhanced (Tuned) loaded successfully
# 2025-07-31 11:37:52,780 - INFO - FT-Transformer Enhanced loaded successfully
# 2025-07-31 11:37:52,804 - INFO - SAINT Enhanced loaded successfully
# 2025-07-31 11:37:52,805 - INFO - Successfully loaded 3 models: ['XGBoost Enhanced', 'FT-Transformer Enhanced', 'SAINT Enhanced']
#    Model expects 43 features, data has 43 features
# ...

# %% [markdown]
# ## 2. Load Enhanced Data
#
# The script automatically loads enhanced data from the XGBoost preprocessing pipeline, which includes:
# - Advanced outlier removal
# - Feature engineering (polynomial, interaction, binned features)
# - Feature selection using mutual information
# - Target transformation when beneficial

# %% [markdown]
# ## 3. Load All Enhanced Models
#
# The script loads all available enhanced models:
# - **XGBoost Enhanced**: Uses enhanced preprocessing with optimized hyperparameters
# - **FT-Transformer Enhanced**: Improved architecture with target scaling
# - **SAINT Enhanced**: Trained on enhanced data with better preprocessing

# %% [markdown]
# ## 4. Generate Predictions for All Models
#
# All models generate predictions on the same enhanced test set, ensuring fair comparison.

# %% [markdown]
# ## 5. Calculate Comprehensive Metrics
#
# The comparison includes multiple regression metrics:
# - **R² Score**: Coefficient of determination
# - **RMSE**: Root Mean Square Error
# - **MAE**: Mean Absolute Error
# - **MAPE**: Mean Absolute Percentage Error
# - **Training Time**: Model training duration
# - **Inference Speed**: Predictions per second

# %% [markdown]
# ## 6. Detailed Performance Analysis
#
# The analysis provides:
# - Model ranking by different metrics
# - Performance categories (Excellent, Good, Moderate, etc.)
# - Statistical significance testing
# - Business impact assessment

# %% [markdown]
# ## 7. Create Comprehensive Visualizations
#
# The script generates a comprehensive visualization dashboard including:
# - Performance metric comparisons
# - Actual vs Predicted scatter plots
# - Residual analysis
# - Error distribution comparisons
# - Performance radar chart
# - Model complexity vs performance
# - Inference speed comparison

# %% [markdown]
# ## 8. Feature Importance Analysis
#
# For models that support it, the script analyzes feature importance:
# - **XGBoost**: Built-in feature importance
# - **Neural Networks**: Permutation importance approximation
# - Cross-model feature importance comparison

# %% [markdown]
# ## 9. Model Summary and Recommendations
#
# The analysis provides specific recommendations for different use cases:
# - **Highest Accuracy**: Best R² score model
# - **Fastest Inference**: Best speed model
# - **Balanced Performance**: Overall best model
# - **Business Impact**: Practical recommendations for deployment

# %% [markdown]
# ## 10. Business Impact Analysis
#
# The script provides business-focused analysis:
# - Average prediction errors in dollar terms
# - Percentage errors relative to average Airbnb prices
# - Business suitability ratings
# - Deployment recommendations

# %% [markdown]
# ## 11. Model Selection Guide
#
# Specific recommendations for different scenarios:
#
# ### Production Deployment (Highest Accuracy)
# - Recommended model based on best R² score
# - Critical for accurate price predictions
#
# ### Real-time Applications (Fastest Inference)
# - Fastest model for real-time price estimation
# - Important for user-facing applications
#
# ### Balanced Performance (Overall Best)
# - Best combination of accuracy, speed, and reliability
# - Recommended for most use cases
#
# ### Research & Development
# - Best performing deep learning model
# - For exploring advanced techniques

# %% [markdown]
# ## 12. Save Results and Prepare for Section 3
#
# All results are saved for further analysis:
# - Model comparison CSV
# - Comprehensive visualizations
# - Feature importance analysis
# - Complete results pickle for Section 3

# %% [markdown]
# ## 13. Final Summary and Next Steps
#
# The comprehensive comparison provides:
# - Complete performance evaluation of all enhanced models
# - Business-focused recommendations
# - Technical insights for model selection
# - Foundation for explainability analysis in Section 3

# %% [markdown]
# ## Summary
#
# This comprehensive comparison reveals several key insights about enhanced models:
#
# ### 🏆 Expected Performance Ranking
# 1. **XGBoost Enhanced** - Likely best overall performance with optimized hyperparameters
# 2. **FT-Transformer Enhanced** - Competitive deep learning performance with proper preprocessing
# 3. **SAINT Enhanced** - Good transformer performance with enhanced data
#
# ### 🔍 Key Insights
# - **Enhanced Data Impact**: All models benefit from advanced preprocessing
# - **Feature Engineering**: Polynomial and interaction features improve performance
# - **Outlier Handling**: Robust preprocessing leads to better model stability
# - **Target Transformation**: Optimal transformations improve neural network training
#
# ### 💼 Business Recommendations
# - **Production Deployment**: Use the highest accuracy model for critical applications
# - **Real-time Applications**: Balance accuracy with inference speed
# - **Cost Considerations**: Factor in training time and computational requirements
#
# ### 🔬 Technical Lessons
# 1. **Preprocessing Quality**: Enhanced preprocessing significantly improves all models
# 2. **Feature Selection**: Mutual information-based selection reduces noise
# 3. **Hyperparameter Tuning**: Systematic optimization yields substantial gains
# 4. **Model Architecture**: Proper neural network design is crucial for performance
#
# This analysis provides a solid foundation for model selection and deployment decisions in Airbnb price prediction systems, with all models benefiting from the enhanced preprocessing pipeline.
