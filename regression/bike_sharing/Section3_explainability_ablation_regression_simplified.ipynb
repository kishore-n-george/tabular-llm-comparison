# %% [markdown]
# # Section 3: Explainability Analysis and Ablation Studies (Simplified)
#
# ## Bike Sharing Dataset - Model Interpretability for Regression
#
# This notebook provides comprehensive explainability analysis and ablation studies for the trained regression models using wrapped functions for better modularity.
#
# **Analysis Components:**
# - **Feature Importance**: Built-in and permutation-based importance
# - **SHAP Analysis**: Shapley Additive Explanations for model predictions
# - **LIME Analysis**: Local Interpretable Model-agnostic Explanations
# - **Ablation Studies**: Feature ablation, hyperparameter sensitivity
# - **Cross-Model Comparison**: Feature importance consensus across models
#
# **Models Analyzed:**
# - XGBoost, Improved FT-Transformer, Original FT-Transformer, SAINT
# - Focus on understanding what drives bike sharing demand prediction
# - Identify most important features for bike rental count prediction

# %% [markdown]
# ## 1. Import Required Libraries and Functions

# %%
# Import the wrapped functions from our custom module
from section3_explainability_functions import (
    setup_analysis_environment,
    load_section2_results,
    load_preprocessed_data,
    load_and_filter_models,
    initialize_explainability_analyzer,
    analyze_xgboost_explainability,
    analyze_improved_ft_transformer_explainability,
    analyze_saint_explainability,
    perform_cross_model_comparison,
    generate_explanation_reports,
    generate_business_insights,
    run_ablation_studies,
    generate_analysis_summary,
    save_final_results,
    run_complete_explainability_analysis
)

# Import additional libraries for display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Memory management utilities
import gc
import pickle
import os

# %% [markdown]
# ## 2. Setup Analysis Environment

# %%
# Setup the analysis environment
setup_analysis_environment()
# Out:
# 🔍 Section 3: Explainability Analysis and Ablation Studies
# Dataset: Bike Sharing Demand Prediction
# Task: Regression
# True

# %% [markdown]
# ## 3. Option 1: Run Complete Analysis Pipeline (Recommended)
#
# This single function call will run the entire explainability analysis pipeline:

# %%
# Run the complete explainability analysis pipeline
results = run_complete_explainability_analysis(
    section2_results_file='./bike_sharing_section2_results.pkl',
    preprocessed_data_file='./bike_sharing_preprocessed_data.pkl',
    model_dir='./Section2_Model_Training',
    save_dir='./Section3_Explainability',
    min_r2_threshold=0.5,
    max_samples=300
)

print("\n🎉 Complete explainability analysis finished!")
print(f"📊 Models analyzed: {results['models_analyzed']}")
print(f"📁 Results saved to: {results['results_file']}")
# Out:
# 🔍 Section 3: Explainability Analysis and Ablation Studies
# Dataset: Bike Sharing Demand Prediction
# Task: Regression
# ✅ Section 2 results loaded successfully!
# Models available: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# Best overall model: XGBoost
# Best R² model: XGBoost
# ✅ Preprocessed data loaded successfully!
# Features: 13
# Test samples: 3,476
#
# 📋 Feature Names:
#     1. instant
#     2. season
#     3. yr
#     4. mnth
#     5. hr
#     6. holiday
#     7. weekday
#     8. workingday
#     9. weathersit
#    10. temp
#    11. atemp
#    12. hum
#    13. windspeed
# 🔄 Loading all available models...
# 📦 Loading XGBoost model...
# 2025-07-27 11:00:46,758 - INFO - Initialized RegressionExplainabilityAnalyzer with 13 features
# 2025-07-27 11:00:46,759 - INFO - Starting explainability analysis for XGBoost
# ✅ XGBoost model loaded successfully!
# 📦 Loading Improved FT-Transformer model...
# ✅ Improved FT-Transformer model loaded successfully!
# 📦 Loading SAINT model...
# ✅ SAINT model loaded successfully!
# ✅ Successfully loaded 3 models: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
#
# 📦 Models Loaded for Analysis:
#    ✅ XGBoost
#    ✅ Improved FT-Transformer
#    ✅ SAINT
#    📊 XGBoost: R² = 0.9546 - Will analyze
#    📊 Improved FT-Transformer: R² = 0.9385 - Will analyze
#    📊 SAINT: R² = 0.9316 - Will analyze
#
# 🔍 Models selected for analysis: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# 🔧 Regression explainability analyzer initialized
# Feature names: ['instant', 'season', 'yr', 'mnth', 'hr']...
# Total features: 13
# Save directory: ./Section3_Explainability
#
# ============================================================
# XGBOOST EXPLAINABILITY ANALYSIS
# ============================================================
#
# 🔍 Analyzing XGBoost explainability...
# 2025-07-27 11:00:46,911 - INFO - Baseline metrics calculated - R²: 0.9546, RMSE: 37.9232
# 2025-07-27 11:00:47,648 - INFO - Built-in feature importance extracted for XGBoost
#       📊 Calculating permutation importance...
# 2025-07-27 11:00:48,457 - INFO - Permutation importance calculated using 300 samples
#       🎯 Performing SHAP analysis...
#          Using GPU for SHAP with 200 samples
#          Creating SHAP plots for XGBoost...
#          ✓ SHAP summary plot saved
#          ✓ SHAP importance plot saved
# 2025-07-27 11:00:49,525 - INFO - SHAP analysis completed for XGBoost with 200 samples
# 2025-07-27 11:00:49,617 - WARNING - Error explaining instance 0: 'hr > 0.79'
# 2025-07-27 11:00:49,713 - WARNING - Error explaining instance 1: 'hr > 0.79'
#       🍋 Performing LIME analysis...
# 2025-07-27 11:00:49,825 - WARNING - Error explaining instance 2: 'hr <= -0.80'
# 2025-07-27 11:00:49,901 - WARNING - Error explaining instance 3: 'hr > 0.79'
# 2025-07-27 11:00:49,979 - WARNING - Error explaining instance 4: 'hr <= -0.80'
# 2025-07-27 11:00:49,980 - INFO - LIME analysis completed for 5 instances
# 2025-07-27 11:00:49,986 - INFO - Completed explainability analysis for XGBoost
# 💾 Intermediate results saved to './Section3_Explainability/XGBoost_explainability_results.pkl'
# 💾 Intermediate results saved to 'bike_sharing_xgb_explanations.pkl'
# ✅ XGBoost explainability analysis completed
#
# 🎯 Top 10 Most Important Features (XGBoost Built-in):
#     1. workingday: 0.2823
#     2. hr: 0.2062
#     3. yr: 0.1725
#     4. temp: 0.0813
#     5. season: 0.0523
#     6. instant: 0.0436
#     7. atemp: 0.0433
#     8. hum: 0.0399
#     9. weathersit: 0.0314
#    10. weekday: 0.0158
# 2025-07-27 11:00:50,300 - INFO - Starting explainability analysis for Improved FT-Transformer
# 2025-07-27 11:00:50,452 - INFO - Baseline metrics calculated - R²: 0.9385, RMSE: 44.1403
# GPU memory allocated: 7.24 MB
# GPU memory cached: 14.00 MB
#
# ============================================================
# IMPROVED FT-TRANSFORMER EXPLAINABILITY ANALYSIS
# ============================================================
#
# 🔍 Analyzing Improved FT-Transformer explainability...
# 🔬 calling predict in wrapper
#       📊 Calculating permutation importance...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:51,481 - INFO - Permutation importance calculated using 300 samples
#       🎯 Performing SHAP analysis...
#          Using CPU for SHAP with 50 samples
#          Using CPU-based KernelExplainer for neural network
# 🔬 calling predict in wrapper
#   0%|          | 0/20 [00:00<?, ?it/s]
# 2025-07-27 11:00:51,660 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:51,660 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:00:51,661 - INFO - num_paired_subset_sizes = 6
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:51,688 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:52,422 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:00:52,423 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:00:52,431 - INFO - phi = array([ -7.55097264,  11.7798876 , -21.42307572,   0.        ,
#         52.52964312,   0.        ,   8.22415242,   8.92425734,
#        -52.75214431,  16.29727505,   7.81990094, -57.46791061,
#          0.        ])
# 2025-07-27 11:00:52,466 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:52,467 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:00:52,469 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:00:52,519 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:53,266 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:00:53,267 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:00:53,273 - INFO - phi = array([-37.61474919, -22.05096348, -22.10644212,  -9.98470674,
#         64.4569278 ,   0.        ,   0.        ,  41.85750791,
#          0.        , -35.15962451, -27.6988135 ,  16.29182708,
#         -4.39606762])
# 2025-07-27 11:00:53,307 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:53,308 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:00:53,309 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:00:53,359 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:54,114 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:00:54,115 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:00:54,122 - INFO - phi = array([  0.        , -11.90257187, -11.73293138,  -8.39872496,
#        -94.22999632,   0.        ,  -1.76147776,  -2.7394107 ,
#          5.97644489, -10.78197737,  -7.50787968, -10.58359063,
#          0.        ])
# 2025-07-27 11:00:54,156 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:54,157 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:00:54,158 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:00:54,210 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:54,967 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:00:54,968 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:00:54,976 - INFO - phi = array([  0.        ,   5.05822253, -39.53568497,   7.56927966,
#        105.37995904,   0.        ,   3.10683235,  45.30474075,
#          9.29958646,  21.59759322,  24.63806993,   5.74431272,
#          0.        ])
# 2025-07-27 11:00:55,006 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:55,008 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:00:55,009 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:00:55,059 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:55,799 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:00:55,800 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:00:55,806 - INFO - phi = array([  -3.36303966,   10.95878528,  -15.0210003 ,    0.        ,
#        -143.19032747,    0.        ,   -1.26465663,    1.27430776,
#           0.        ,   10.0787325 ,    8.40142389,  -14.15894433,
#           1.38128542])
# 2025-07-27 11:00:55,838 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:55,839 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:00:55,840 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:00:55,891 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:56,625 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:00:56,626 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:00:56,633 - INFO - phi = array([  0.        ,  25.94719832, -29.90940117, -12.16973052,
#         14.2946331 ,   0.        ,  15.63831603,   0.        ,
#          8.24473773,   8.62466273,  10.6686986 ,  10.5462195 ,
#          1.70895859])
# 2025-07-27 11:00:56,665 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:56,666 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:00:56,668 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:00:56,719 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:00:57,470 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:00:57,471 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:00:57,477 - INFO - phi = array([ -11.9242644 ,    0.        ,  -12.87659193,    5.0743085 ,
#        -136.18795509,    0.        ,   -1.69261626,   -1.95571565,
#           0.        ,   11.64342248,   10.03744888,   -9.50335088,
#          -5.56407865])
# 2025-07-27 11:00:57,508 - INFO - num_full_subsets = 3
# 2025-07-27 11:00:57,511 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11
- INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:04,976 - INFO - np.sum(w_aug) = 13.0
# 2025-07-27 11:01:04,977 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:04,984 - INFO - phi = array([  -5.23458459,    2.94991394,  -13.57031395,   -2.45137987,
#        -128.22087017,    0.        ,    0.        ,   20.03179309,
#           5.64087154,   14.15952395,   11.5347855 ,  -19.93435033,
#           0.        ])
# 2025-07-27 11:01:05,015 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:05,016 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:05,017 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:05,068 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:05,797 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:05,798 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:05,804 - INFO - phi = array([  0.        ,  26.01998326, -23.5432632 , -13.03776122,
#         49.10965646,   0.        ,  11.02734378, -27.65602565,
#          0.        , -42.30209972, -33.44766632, -22.75193748,
#         -8.47507531])
# 2025-07-27 11:01:05,835 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:05,836 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:05,837 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:05,888 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:06,628 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:01:06,629 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:06,635 - INFO - phi = array([ 23.15663635,   4.20841005,  23.19777691,   4.25582442,
#          0.        ,   0.        , -15.17729102, -21.28707764,
#          2.67167018,  24.90507879,  19.09281298,   0.        ,
#          2.75284018])
# 2025-07-27 11:01:06,667 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:06,669 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:06,671 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:06,722 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:07,454 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:01:07,455 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:07,461 - INFO - phi = array([  10.48487527,    4.55405488,   12.57512509,    1.02228038,
#        -197.57489631,    0.        ,    0.        ,    1.5059702 ,
#           5.83379866,   13.47672913,   11.83966505,    0.        ,
#           0.60098712])
# 2025-07-27 11:01:07,493 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:07,495 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:07,496 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:07,546 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:08,297 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:08,297 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:08,303 - INFO - phi = array([ 14.61499447,   0.        ,  54.57948444,  17.95406325,
#        353.67526343,   0.        ,  14.62909589,  34.36120139,
#         16.48675036,  43.95629574,  39.62137677,   6.63857295,
#          0.        ])
#          Creating SHAP plots for Improved FT-Transformer...
#          ✓ SHAP summary plot saved
# 2025-07-27 11:01:09,130 - INFO - SHAP analysis completed for Improved FT-Transformer with 20 samples
#          ✓ SHAP importance plot saved
#       🍋 Performing LIME analysis...
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:09,251 - WARNING - Error explaining instance 0: 'hr > 0.79'
# 2025-07-27 11:01:09,399 - WARNING - Error explaining instance 1: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:09,543 - WARNING - Error explaining instance 2: 'hr <= -0.80'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:09,693 - WARNING - Error explaining instance 3: 'hr > 0.79'
# 2025-07-27 11:01:09,837 - WARNING - Error explaining instance 4: 'hr <= -0.80'
# 2025-07-27 11:01:09,839 - INFO - LIME analysis completed for 5 instances
# 2025-07-27 11:01:09,844 - INFO - Completed explainability analysis for Improved FT-Transformer
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 💾 Intermediate results saved to './Section3_Explainability/Improved FT-Transformer_explainability_results.pkl'
# 💾 Intermediate results saved to 'bike_sharing_improved_ft_explanations.pkl'
# ✅ Improved FT-Transformer explainability analysis completed
#
# 🎯 Top 10 Most Important Features (Improved FT-Transformer - Permutation):
#     1. hr: 1.6106
#     2. workingday: 0.2607
#     3. yr: 0.0725
#     4. temp: 0.0660
#     5. weathersit: 0.0389
#     6. atemp: 0.0384
#     7. hum: 0.0367
#     8. instant: 0.0348
#     9. season: 0.0323
#    10. weekday: 0.0301
# 2025-07-27 11:01:10,152 - INFO - Starting explainability analysis for SAINT
# 2025-07-27 11:01:10,331 - INFO - Baseline metrics calculated - R²: 0.9307, RMSE: 46.8501
# GPU memory allocated: 15.37 MB
# GPU memory cached: 34.00 MB
#
# ============================================================
# SAINT EXPLAINABILITY ANALYSIS
# ============================================================
#
# 🔍 Analyzing SAINT explainability...
# 🔬 calling predict in wrapper
#       📊 Calculating permutation importance...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:12,192 - INFO - Permutation importance calculated using 300 samples
#       🎯 Performing SHAP analysis...
#          Using CPU for SHAP with 50 samples
#          Using CPU-based KernelExplainer for neural network
# 🔬 calling predict in wrapper
#   0%|          | 0/20 [00:00<?, ?it/s]
# 2025-07-27 11:01:12,375 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:12,376 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:12,376 - INFO - num_paired_subset_sizes = 6
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:12,403 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:17,153 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:01:17,154 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:17,161 - INFO - phi = array([ 17.89187979,  15.56259654,  38.79445344,   6.64887111,
#          0.        ,   0.        ,   0.        , -53.76097998,
#         13.44193281,  36.26744936,  18.92281873,  22.17619899,
#          5.50872218])
# 2025-07-27 11:01:17,206 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:17,210 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:17,212 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:17,264 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:22,025 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:22,025 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:22,032 - INFO - phi = array([-15.53350969,   0.        , -34.95201436,   9.26746954,
#         29.21957651,   2.20674941,   5.39714205,   0.        ,
#          0.        ,   7.52103871,   8.94082791,   6.12014897,
#          3.60092556])
# 2025-07-27 11:01:22,079 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:22,082 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:22,085 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:22,137 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:26,920 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:26,921 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:26,928 - INFO - phi = array([  0.        ,  15.45986741, -31.87464562,   8.24343236,
#          5.81264954,   4.7169552 ,   0.        , -37.70944784,
#         14.23274629,  34.49755268,  21.65566356,  27.40177437,
#          0.        ])
# 2025-07-27 11:01:26,965 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:26,967 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:26,968 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:27,019 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:31,815 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:31,816 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:01:31,822 - INFO - phi = array([  16.03691552,    0.        ,   32.768415  ,   13.56232881,
#        -123.20581988,    7.79118176,    0.        ,    0.        ,
#          16.64887394,   31.94692653,   21.68429491,   10.0135408 ,
#          12.92321271])
# 2025-07-27 11:01:31,867 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:31,871 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:31,874 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:31,925 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:36,710 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:01:36,711 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:01:36,717 - INFO - phi = array([23.49622363, 17.14730125, 40.77768775,  7.66334271,  0.        ,
#         4.82581685,  0.        ,  0.        , 14.22862386, 30.77105849,
#        14.350392  , 18.36833124,  6.6600651 ])
# 2025-07-27 11:01:36,760 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:36,763 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:36,766 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:36,817 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:41,624 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:41,625 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:01:41,630 - INFO - phi = array([-34.54892473, -37.18887519, -33.47847415,  -3.39169009,
#         50.83407972,   0.        ,   0.        ,  13.01364618,
#         -1.68411877, -52.68932074, -22.56995959,   6.33447547,
#          0.        ])
# 2025-07-27 11:01:41,669 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:41,671 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:41,673 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:41,725 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:46,551 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:46,552 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:01:46,558 - INFO - phi = array([-18.18229229,   0.        , -35.69652873,   9.83500836,
#         28.98774916,   0.        ,   7.25339211,   0.        ,
#         12.39765602,  -5.41931633,   3.24748773,  11.99405672,
#          6.21289296])
# 2025-07-27 11:01:46,597 - INFO - num_full_subsets = 3
# 2025-07-27 11:01:46,599 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:01:46,602 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:01:46,655 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:01:51,460 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:01:51,461 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11
- INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:02:30,855 - INFO - phi = array([  0.        ,  -6.53320315,  37.70708949, -15.85271618,
#        204.30457616, -19.13010277, -16.31068085,  30.2224429 ,
#          0.        ,  -8.35709659, -23.58533714,   0.        ,
#        -16.11082137])
# 2025-07-27 11:02:30,893 - INFO - num_full_subsets = 3
# 2025-07-27 11:02:30,894 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:02:30,895 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:02:30,947 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:35,778 - INFO - np.sum(w_aug) = 13.0
# 2025-07-27 11:02:35,779 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:02:35,786 - INFO - phi = array([  3.11823518,   0.        ,  27.17063584,   0.        ,
#         90.24187097,  -9.09272513, -30.23327677,  62.92260686,
#          3.34731343,   9.51336306, -21.94058615,  21.16480646,
#          0.        ])
# 2025-07-27 11:02:35,822 - INFO - num_full_subsets = 3
# 2025-07-27 11:02:35,824 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:02:35,825 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:02:35,875 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:40,707 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:02:40,708 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 11:02:40,716 - INFO - phi = array([  -9.83034115,  -10.11837456,  -10.27935763,    0.        ,
#        -150.94291166,    0.        ,    0.        ,   -8.79401393,
#           8.06851798,  -16.19300899,   -8.39111554,    9.90676692,
#           5.96811871])
# 2025-07-27 11:02:40,759 - INFO - num_full_subsets = 3
# 2025-07-27 11:02:40,761 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:02:40,762 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:02:40,812 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:45,643 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 11:02:45,644 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:02:45,650 - INFO - phi = array([ 10.37782261,  28.67864705, -27.27019171,   3.37282741,
#          0.        ,   8.72773131,   2.91716614, -27.47630912,
#         17.06848427,  -7.1865196 ,   0.        ,  24.83304499,
#          0.        ])
# 2025-07-27 11:02:45,690 - INFO - num_full_subsets = 3
# 2025-07-27 11:02:45,692 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 11:02:45,693 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 11:02:45,743 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:50,577 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 11:02:50,577 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 11:02:50,584 - INFO - phi = array([   0.        ,    9.65678044,  -15.83523638,    4.19544265,
#        -185.2201708 ,    3.25524762,    0.        ,  -12.0100635 ,
#           9.63975419,   17.43902518,   12.35300199,    0.        ,
#           6.04630081])
#          Creating SHAP plots for SAINT...
#          ✓ SHAP summary plot saved
# 2025-07-27 11:02:51,398 - INFO - SHAP analysis completed for SAINT with 20 samples
#          ✓ SHAP importance plot saved
#       🍋 Performing LIME analysis...
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:51,698 - WARNING - Error explaining instance 0: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:52,012 - WARNING - Error explaining instance 1: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:52,326 - WARNING - Error explaining instance 2: 'hr <= -0.80'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:52,641 - WARNING - Error explaining instance 3: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 11:02:52,954 - WARNING - Error explaining instance 4: 'hr <= -0.80'
# 2025-07-27 11:02:52,955 - INFO - LIME analysis completed for 5 instances
# 2025-07-27 11:02:52,960 - INFO - Completed explainability analysis for SAINT
# 🔬 calling predict in wrapper
# 💾 Intermediate results saved to './Section3_Explainability/SAINT_explainability_results.pkl'
# 💾 Intermediate results saved to 'bike_sharing_saint_explanations.pkl'
# ✅ SAINT explainability analysis completed
#
# 🎯 Top 10 Most Important Features (SAINT - Permutation):
#     1. hr: 1.4751
#     2. workingday: 0.3905
#     3. yr: 0.1090
#     4. temp: 0.0719
#     5. hum: 0.0489
#     6. season: 0.0407
#     7. weathersit: 0.0401
#     8. atemp: 0.0301
#     9. weekday: 0.0169
#    10. instant: 0.0121
#
# GPU memory allocated: 15.37 MB
# GPU memory cached: 34.00 MB
#
# ============================================================
# CROSS-MODEL FEATURE IMPORTANCE COMPARISON
# ============================================================
#
# GPU memory allocated: 15.37 MB
# GPU memory cached: 34.00 MB
#
# 🔄 Comparing feature importance across models...
# 2025-07-27 11:02:55,661 - INFO - Feature importance comparison completed
# 📊 Feature Importance Comparison Table:
#             XGBoost_permutation  XGBoost_builtin  XGBoost_shap  Improved FT-Transformer_permutation  Improved FT-Transformer_shap  SAINT_permutation  SAINT_shap
# instant                  0.0768           0.0436        0.1162                               0.0153                        0.0437             0.0054      0.0393
# season                   0.0055           0.0523        0.0303                               0.0142                        0.0559             0.0181      0.0675
# yr                       0.0112           0.1725        0.0527                               0.0320                        0.0968             0.0485      0.1268
# mnth                     0.0024           0.0137        0.0090                               0.0125                        0.0308             0.0032      0.0319
# hr                       0.7141           0.2062        0.4224                               0.7096                        0.4177             0.6558      0.3169
# holiday                  0.0002           0.0102        0.0019                               0.0053                        0.0021             0.0010      0.0184
# weekday                  0.0115           0.0158        0.0267                               0.0133                        0.0244             0.0075      0.0325
# workingday               0.0972           0.2823        0.0825                               0.1149                        0.0909             0.1736      0.0814
# weathersit               0.0098           0.0314        0.0340                               0.0171                        0.0329             0.0178      0.0394
# temp                     0.0377           0.0813        0.1153                               0.0291                        0.0831             0.0320      0.1032
# atemp                    0.0122           0.0433        0.0442                               0.0169                        0.0631             0.0134      0.0627
# hum                      0.0212           0.0399        0.0555                               0.0162                        0.0517             0.0217      0.0606
# windspeed                0.0003           0.0074        0.0095                               0.0038                        0.0068             0.0021      0.0195
#
# 💾 Feature importance comparison saved to './Section3_Explainability/bike_sharing_feature_importance_comparison.csv'
#
# 🎯 FEATURE IMPORTANCE CONSENSUS:
#
# Top 10 Most Important Features (Average Across All Methods):
#     1. hr: 0.4918
#     2. workingday: 0.1318
#     3. yr: 0.0772
#     4. temp: 0.0688
#     5. instant: 0.0486
#     6. hum: 0.0381
#     7. atemp: 0.0365
#     8. season: 0.0348
#     9. weathersit: 0.0261
#    10. weekday: 0.0188
#
# 🔗 Feature Importance Correlation Between Methods:
#                                      XGBoost_permutation  XGBoost_builtin  XGBoost_shap  Improved FT-Transformer_permutation  Improved FT-Transformer_shap  SAINT_permutation  SAINT_shap
# XGBoost_permutation                                1.000            0.534         0.972                                0.995                         0.970              0.984       0.919
# XGBoost_builtin                                    0.534            1.000         0.558                                0.564                         0.626              0.646       0.660
# XGBoost_shap                                       0.972            0.558         1.000                                0.953                         0.966              0.943       0.935
# Improved FT-Transformer_permutation                0.995            0.564         0.953                                1.000                         0.976              0.994       0.931
# Improved FT-Transformer_shap                       0.970            0.626         0.966                                0.976                         1.000              0.974       0.984
# SAINT_permutation                                  0.984            0.646         0.943                                0.994                         0.974              1.000       0.934
# SAINT_shap                                         0.919            0.660         0.935                                0.931                         0.984              0.934       1.000
#
# ============================================================
# DETAILED EXPLANATION REPORTS
# ============================================================
# Available models for reporting: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
#
# ==================================================
# EXPLANATION REPORT: XGBoost
# ==================================================
#
# 📋 EXPLANATION REPORT: XGBoost
# ============================================================
#
# 📊 Baseline Performance:
#    R² Score: 0.9546
#    RMSE: 37.9232
#    MAE: 23.8845
#    MAPE: 0.45%
#    Training Time: 0.145s
#    Inference Time: 0.004s
#
# 🎯 Top 10 Most Important Features (Permutation):
#     1. hr: 1.3948
#     2. workingday: 0.1899
#     3. instant: 0.1500
#     4. temp: 0.0736
#     5. hum: 0.0413
#     6. atemp: 0.0238
#     7. weekday: 0.0225
#     8. yr: 0.0219
#     9. weathersit: 0.0192
#    10. season: 0.0107
#
# 🏗️ Top 10 Most Important Features (Built-in):
#     1. workingday: 0.2823
#     2. hr: 0.2062
#     3. yr: 0.1725
#     4. temp: 0.0813
#     5. season: 0.0523
#     6. instant: 0.0436
#     7. atemp: 0.0433
#     8. hum: 0.0399
#     9. weathersit: 0.0314
#    10. weekday: 0.0158
#
# 🎯 SHAP Analysis:
#    Explainer Type: TreeExplainer
#    Samples Analyzed: 200
#    Top 5 SHAP Features:
#       1. hr: 104.1481
#       2. instant: 28.6591
#       3. temp: 28.4303
#       4. workingday: 20.3394
#       5. hum: 13.6896
#
# 🍋 LIME Analysis:
#    Instances Explained: 0
#    Top 5 LIME Features:
#
# ✅ Report completed for XGBoost
#
# ----------------------------------------
#
# ==================================================
# EXPLANATION REPORT: Improved FT-Transformer
# ==================================================
#
# 📋 EXPLANATION REPORT: Improved FT-Transformer
# ============================================================
#
# 📊 Baseline Performance:
#    R² Score: 0.9385
#    RMSE: 44.1403
#    MAE: 27.9566
#    MAPE: 0.39%
# ...
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0841
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9281
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9646
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1743
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0958
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1128
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0463
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9958
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1662
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.7971
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9186
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9554
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0744
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9878
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0486
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9879
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8981
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8976
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0188
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8509
#       📊 Data size ablation study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#       🔊 Noise robustness study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#    🧪 Running SAINT-specific ablations...
#         🏗️ Architecture ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         📚 Training hyperparameter ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         💻 Device performance ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         🎯 Attention mechanism ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 💾 SAINT ablation results saved to 'bike_sharing_ablation_SAINT.pkl'
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#
# 🔄 Running comparative analysis...
#       🎯 Comparing feature importance...
#       🛡️ Comparing model robustness...
#       ⚡ Comparing computational efficiency...
# 📋 COMPREHENSIVE ABLATION STUDY REPORT
# ================================================================================
#
# 📊 BASELINE PERFORMANCE SUMMARY
# --------------------------------------------------
#
# XGBoost:
#   R² Score: 0.9546
#   RMSE: 37.9232
#   MAE: 23.8845
#   MSE: 1438.1665
#   MAPE: 0.45%
#   Explained Variance: 0.9546
#   Train Time: 0.151s
#   Inference Time: 0.004s
#
# Improved FT-Transformer:
#   R² Score: -1.0704
#   RMSE: 256.0469
#   MAE: 184.8185
#   MSE: 65560.0103
#   MAPE: 1.02%
#   Explained Variance: 0.0083
#   Train Time: 0.000s
#   Inference Time: 0.027s
#
# SAINT:
#   R² Score: 0.9307
#   RMSE: 46.8501
#   MAE: 29.7511
#   MSE: 2194.9274
#   MAPE: 0.34%
#   Explained Variance: 0.9309
#   Train Time: 0.000s
#   Inference Time: 0.160s
#
# 🎯 FEATURE IMPORTANCE INSIGHTS
# --------------------------------------------------
#
# XGBoost - Top 3 Most Important Features:
#   1. hr: R² drop = 0.4859 (50.9% relative importance)
#   2. weekday: R² drop = 0.0114 (1.2% relative importance)
#   3. workingday: R² drop = 0.0079 (0.8% relative importance)
#
# Improved FT-Transformer - Top 3 Most Important Features:
#   1. hr: R² drop = -1.4239 (0.0% relative importance)
#   2. atemp: R² drop = -1.5834 (0.0% relative importance)
#   3. hum: R² drop = -1.6212 (0.0% relative importance)
#
# SAINT - Top 3 Most Important Features:
#   1. mnth: R² drop = 2.1644 (232.6% relative importance)
#   2. season: R² drop = 2.1108 (226.8% relative importance)
#   3. weathersit: R² drop = 2.1007 (225.7% relative importance)
#
# 🔬 MODEL-SPECIFIC INSIGHTS
# --------------------------------------------------
#
# XGBoost:
#
# Improved FT-Transformer:
#
# SAINT:
#
# 🛡️ ROBUSTNESS RANKING
# --------------------------------------------------
#    1. SAINT: 0.777
#    2. XGBoost: 0.614
#    3. Improved FT-Transformer: 0.000
#
# ⚡ EFFICIENCY RANKING
# --------------------------------------------------
#
# Fastest Training:
#    1. Improved FT-Transformer: 0.000s
#    2. SAINT: 0.000s
#    3. XGBoost: 0.151s
#
# Fastest Inference:
#    1. XGBoost: 0.004s
#    2. Improved FT-Transformer: 0.027s
#    3. SAINT: 0.160s
#
# 🎯 FINAL RECOMMENDATIONS
# --------------------------------------------------
#
# 1. Best Overall Performance: [Based on R² scores and RMSE]
# 2. Most Robust Model: [Based on noise robustness analysis]
# 3. Most Efficient Model: [Based on training/inference time]
# 4. Most Feature-Dependent: [Based on feature ablation results]
# 5. Best for Production: [Balanced performance, efficiency, and robustness]
#
# ✅ Comprehensive ablation study analysis complete!
# 💾 Comprehensive ablation results saved to 'bike_sharing_section5_ablation_results.pkl'
# 📋 Contains results for 3 models
#
# ✅ Ablation studies completed successfully!
#
# 📊 Ablation Study Summary:
#                   Model  R2_Score       RMSE        MAE          MSE     MAPE  Explained_Variance   Train_Time  Inference_Time Most_Important_Feature  Feature_Importance_Score  Robustness_Score
#                 XGBoost  0.954582  37.923165  23.884511  1438.166460 0.452483            0.954586 1.506319e-01        0.004269                     hr                  0.509018          0.614141
# Improved FT-Transformer -1.070398 256.046891 184.818495 65560.010250 1.021158            0.008314 7.152557e-07        0.027261                     hr                  0.000000          0.000000
#                   SAINT  0.930684  46.850052  29.751069  2194.927356 0.342723            0.930898 7.152557e-07        0.160068                   mnth                  2.325563          0.776720
# ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# [0.15063190460205078, 7.152557373046875e-07, 7.152557373046875e-07]
# 2025-07-27 11:14:27,610 - INFO - Comprehensive results saved to ./Section3_Explainability/comprehensive_explainability_results.pkl
# ================================================================================
# EXPLAINABILITY ANALYSIS SUMMARY
# ================================================================================
#
# 🏆 MODEL PERFORMANCE RECAP:
#    R²_Score     RMSE      MAE    MAPE
# 0    0.9546  37.9232  23.8845  0.4525
# 1    0.9385  44.1403  27.9566  0.3941
# 2    0.9316  46.5453  29.5580  0.3389
#
# 🎯 KEY FEATURE IMPORTANCE INSIGHTS:
#
# Most Important Features for Bike Sharing Demand Prediction:
#    1. hr: 0.4918
#    2. workingday: 0.1318
#    3. yr: 0.0772
#    4. temp: 0.0688
#    5. instant: 0.0486
#
# Feature Importance Consensus: 13 features analyzed
# Top feature: hr (0.4918)
#
# 📋 KEY FINDINGS:
#
# • Bike sharing demand is primarily driven by weather and temporal factors
# • Temperature and humidity are consistently the most important features
# • Hour of day and seasonal patterns are strong indicators of usage
# • Different models may prioritize different feature combinations
# • Feature importance consensus helps identify robust predictors
# • Model interpretability varies significantly across architectures
# • XGBoost provides the best balance of performance and interpretability
#
# ✅ Section 3 completed successfully!
# 📊 Comprehensive explainability analysis finished
# 📁 All results and visualizations saved
# 🎯 Ready for deployment and business implementation
# 💾 Section 3 explainability results saved to 'bike_sharing_section3_explainability.pkl'
# 📋 This file contains all explainability analysis results
# 💾 Intermediate results saved to './Section3_Explainability/comprehensive_explainability_results.pkl'
#
# 🎉 Bike Sharing Explainability Analysis Complete!
#
# 📊 Generated Files:
#    - Feature importance comparison CSV
#    - Feature importance correlation heatmap
#    - Top features comparison visualization
#    - Individual model explanation plots (SHAP, LIME, etc.)
#    - Comprehensive explainability results pickle file
#    - Ablation study results and visualizations
#    - Analysis log file
#
# 🚀 Ready for business implementation and model deployment!
#
# 🎉 Complete explainability analysis finished!
# 📊 Models analyzed: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# 📁 Results saved to: bike_sharing_section3_explainability.pkl

# %% [markdown]
# ## 4. Option 2: Step-by-Step Analysis (For Detailed Control)
#
# If you prefer to run the analysis step-by-step for more control, use the following cells:

# %% [markdown]
# ### 4.1 Load Data and Models

# %%
# Load Section 2 results
section2_data = load_section2_results('./bike_sharing_section2_results.pkl')

# Load preprocessed data
preprocessing_data = load_preprocessed_data('./bike_sharing_preprocessed_data.pkl')

# Extract variables
comparison_df = section2_data['comparison_df']
predictions = section2_data['predictions']
feature_names = preprocessing_data['feature_names']
X_train_scaled = preprocessing_data['X_train_scaled']
X_test_scaled = preprocessing_data['X_test_scaled']
y_train = preprocessing_data['y_train']
y_test = preprocessing_data['y_test']

print(f"\n📊 Data loaded successfully!")
print(f"Features: {len(feature_names)}")
print(f"Training samples: {len(X_train_scaled):,}")
print(f"Test samples: {len(X_test_scaled):,}")
# Out:
# ✅ Section 2 results loaded successfully!
# Models available: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# Best overall model: XGBoost
# Best R² model: XGBoost
# ✅ Preprocessed data loaded successfully!
# Features: 13
# Test samples: 3,476
#
# 📋 Feature Names:
#     1. instant
#     2. season
#     3. yr
#     4. mnth
#     5. hr
#     6. holiday
#     7. weekday
#     8. workingday
#     9. weathersit
#    10. temp
#    11. atemp
#    12. hum
#    13. windspeed
#
# 📊 Data loaded successfully!
# Features: 13
# Training samples: 11,122
# Test samples: 3,476

# %% [markdown]
# ### 4.2 Load and Filter Models

# %%
# Load and filter models based on performance
models_to_analyze, device, model_results_detailed = load_and_filter_models(
    model_dir='./Section2_Model_Training',
    feature_names=feature_names,
    predictions=predictions,
    comparison_df=comparison_df,
    min_r2_threshold=0.5
)

print(f"\n🔍 Models selected for analysis: {list(models_to_analyze.keys())}")
# Out:
# 🔄 Loading all available models...
# 📦 Loading XGBoost model...
# ✅ XGBoost model loaded successfully!
# 📦 Loading Improved FT-Transformer model...
# ✅ Improved FT-Transformer model loaded successfully!
# 📦 Loading SAINT model...
# ✅ SAINT model loaded successfully!
# ✅ Successfully loaded 3 models: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
#
# 📦 Models Loaded for Analysis:
#    ✅ XGBoost
#    ✅ Improved FT-Transformer
#    ✅ SAINT
#    📊 XGBoost: R² = 0.9546 - Will analyze
#    📊 Improved FT-Transformer: R² = 0.9385 - Will analyze
#    📊 SAINT: R² = 0.9316 - Will analyze
#
# 🔍 Models selected for analysis: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
#
# 🔍 Models selected for analysis: ['XGBoost', 'Improved FT-Transformer', 'SAINT']

# %% [markdown]
# ### 4.3 Initialize Explainability Analyzer

# %%
# Initialize the explainability analyzer
explainer = initialize_explainability_analyzer(
    feature_names=feature_names,
    save_dir='./Section3_Explainability'
)

# Store intermediate results
intermediate_results = {}
# Out:
# 2025-07-27 10:42:30,385 - INFO - Initialized RegressionExplainabilityAnalyzer with 13 features
# 🔧 Regression explainability analyzer initialized
# Feature names: ['instant', 'season', 'yr', 'mnth', 'hr']...
# Total features: 13
# Save directory: ./Section3_Explainability

# %% [markdown]
# ### 4.4 Run Model-Specific Explainability Analysis

# %%
# Analyze XGBoost explainability
xgb_results = analyze_xgboost_explainability(
    models_to_analyze, explainer, X_train_scaled, X_test_scaled, 
    y_train, y_test, feature_names, max_samples=300
)
if xgb_results:
    intermediate_results['xgb_explanations'] = xgb_results
# Out:
# 2025-07-27 10:15:39,346 - INFO - Starting explainability analysis for XGBoost
# 2025-07-27 10:15:39,508 - INFO - Baseline metrics calculated - R²: 0.9546, RMSE: 37.9232
# ============================================================
# XGBOOST EXPLAINABILITY ANALYSIS
# ============================================================
#
# 🔍 Analyzing XGBoost explainability...
# 2025-07-27 10:15:40,264 - INFO - Built-in feature importance extracted for XGBoost
#       📊 Calculating permutation importance...
# 2025-07-27 10:15:41,087 - INFO - Permutation importance calculated using 300 samples
#       🎯 Performing SHAP analysis...
#          Using GPU for SHAP with 200 samples
#          Creating SHAP plots for XGBoost...
#          ✓ SHAP summary plot saved
# 2025-07-27 10:15:42,190 - INFO - SHAP analysis completed for XGBoost with 200 samples
#          ✓ SHAP importance plot saved
#       🍋 Performing LIME analysis...
# 2025-07-27 10:15:42,322 - WARNING - Error explaining instance 0: 'hr > 0.79'
# 2025-07-27 10:15:42,492 - WARNING - Error explaining instance 1: 'hr > 0.79'
# 2025-07-27 10:15:42,602 - WARNING - Error explaining instance 2: 'hr <= -0.80'
# 2025-07-27 10:15:42,679 - WARNING - Error explaining instance 3: 'hr > 0.79'
# 2025-07-27 10:15:42,759 - WARNING - Error explaining instance 4: 'hr <= -0.80'
# 2025-07-27 10:15:42,760 - INFO - LIME analysis completed for 5 instances
# 2025-07-27 10:15:42,764 - INFO - Completed explainability analysis for XGBoost
# 💾 Intermediate results saved to './Section3_Explainability/XGBoost_explainability_results.pkl'
# 💾 Intermediate results saved to 'bike_sharing_xgb_explanations.pkl'
# ✅ XGBoost explainability analysis completed
#
# 🎯 Top 10 Most Important Features (XGBoost Built-in):
#     1. workingday: 0.2823
#     2. hr: 0.2062
#     3. yr: 0.1725
#     4. temp: 0.0813
#     5. season: 0.0523
#     6. instant: 0.0436
#     7. atemp: 0.0433
#     8. hum: 0.0399
#     9. weathersit: 0.0314
#    10. weekday: 0.0158
#
# GPU memory allocated: 7.24 MB
# GPU memory cached: 14.00 MB

# %%
# Analyze Improved FT-Transformer explainability
ft_results = analyze_improved_ft_transformer_explainability(
    models_to_analyze, explainer, X_train_scaled, X_test_scaled, 
    y_train, y_test, feature_names, model_results_detailed, device, max_samples=300
)
if ft_results:
    intermediate_results['improved_ft_explanations'] = ft_results
# Out:
# 2025-07-27 10:16:16,078 - INFO - Starting explainability analysis for Improved FT-Transformer
# 2025-07-27 10:16:16,232 - INFO - Baseline metrics calculated - R²: 0.9385, RMSE: 44.1403
# ============================================================
# IMPROVED FT-TRANSFORMER EXPLAINABILITY ANALYSIS
# ============================================================
#
# 🔍 Analyzing Improved FT-Transformer explainability...
# 🔬 calling predict in wrapper
#       📊 Calculating permutation importance...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:17,288 - INFO - Permutation importance calculated using 300 samples
#       🎯 Performing SHAP analysis...
#          Using CPU for SHAP with 50 samples
#          Using CPU-based KernelExplainer for neural network
# 🔬 calling predict in wrapper
#   0%|          | 0/20 [00:00<?, ?it/s]
# 2025-07-27 10:16:17,473 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:17,474 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:17,475 - INFO - num_paired_subset_sizes = 6
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:17,502 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:18,236 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:16:18,237 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:18,244 - INFO - phi = array([ -7.55097264,  11.7798876 , -21.42307572,   0.        ,
#         52.52964312,   0.        ,   8.22415242,   8.92425734,
#        -52.75214431,  16.29727505,   7.81990094, -57.46791061,
#          0.        ])
# 2025-07-27 10:16:18,284 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:18,286 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:18,288 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:18,341 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:19,080 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:16:19,081 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:19,088 - INFO - phi = array([-37.61474919, -22.05096348, -22.10644212,  -9.98470674,
#         64.4569278 ,   0.        ,   0.        ,  41.85750791,
#          0.        , -35.15962451, -27.6988135 ,  16.29182708,
#         -4.39606762])
# 2025-07-27 10:16:19,122 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:19,124 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:19,125 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:19,175 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:19,908 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:16:19,909 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 10:16:19,914 - INFO - phi = array([  0.        , -11.90257187, -11.73293138,  -8.39872496,
#        -94.22999632,   0.        ,  -1.76147776,  -2.7394107 ,
#          5.97644489, -10.78197737,  -7.50787968, -10.58359063,
#          0.        ])
# 2025-07-27 10:16:19,947 - INFO - num_full_subsets = 3
# 2025-07-27 10:16
- INFO - num_full_subsets = 3
# 2025-07-27 10:16:27,463 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:27,466 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:27,519 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:28,256 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 10:16:28,257 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:28,264 - INFO - phi = array([-41.24911433, -15.14402621, -22.68027341,  -6.07871374,
#         58.40985349,   0.        ,   0.        ,  12.66581912,
#          0.        , -22.79038666, -17.49925917,   8.93114143,
#         -9.25013604])
# 2025-07-27 10:16:28,296 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:28,298 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:28,298 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:28,348 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:29,088 - INFO - np.sum(w_aug) = 13.0
# 2025-07-27 10:16:29,088 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:29,106 - INFO - phi = array([-26.09555414,   0.        , -38.01843999,  17.23463566,
#        132.63325167,   0.        ,  27.3771599 ,  82.58626957,
#          9.36224103,  43.64353819,  34.90925039,  23.04990756,
#          0.        ])
# 2025-07-27 10:16:29,139 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:29,141 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:29,142 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:29,193 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:29,930 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:16:29,931 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:29,938 - INFO - phi = array([ 32.10027604,   5.39259588,  51.10123259,   9.6001727 ,
#        292.14953541,   0.        ,   0.        ,  73.26604923,
#         13.50867504,   8.90885606,  11.97945076,  13.86322129,
#          0.        ])
# 2025-07-27 10:16:29,970 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:29,971 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:29,974 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:30,025 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:30,759 - INFO - np.sum(w_aug) = 13.0
# 2025-07-27 10:16:30,760 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:30,767 - INFO - phi = array([  -5.23458459,    2.94991394,  -13.57031395,   -2.45137987,
#        -128.22087017,    0.        ,    0.        ,   20.03179309,
#           5.64087154,   14.15952395,   11.5347855 ,  -19.93435033,
#           0.        ])
# 2025-07-27 10:16:30,801 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:30,803 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:30,804 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:30,854 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:31,591 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:16:31,592 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:31,599 - INFO - phi = array([  0.        ,  26.01998326, -23.5432632 , -13.03776122,
#         49.10965646,   0.        ,  11.02734378, -27.65602565,
#          0.        , -42.30209972, -33.44766632, -22.75193748,
#         -8.47507531])
# 2025-07-27 10:16:31,632 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:31,634 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:31,636 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:31,686 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:32,422 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 10:16:32,423 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:32,431 - INFO - phi = array([ 23.15663635,   4.20841005,  23.19777691,   4.25582442,
#          0.        ,   0.        , -15.17729102, -21.28707764,
#          2.67167018,  24.90507879,  19.09281298,   0.        ,
#          2.75284018])
# 2025-07-27 10:16:32,463 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:32,465 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:32,466 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:32,517 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:33,273 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 10:16:33,274 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:33,280 - INFO - phi = array([  10.48487527,    4.55405488,   12.57512509,    1.02228038,
#        -197.57489631,    0.        ,    0.        ,    1.5059702 ,
#           5.83379866,   13.47672913,   11.83966505,    0.        ,
#           0.60098712])
# 2025-07-27 10:16:33,312 - INFO - num_full_subsets = 3
# 2025-07-27 10:16:33,314 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:16:33,315 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:16:33,366 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:34,118 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:16:34,119 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:16:34,125 - INFO - phi = array([ 14.61499447,   0.        ,  54.57948444,  17.95406325,
#        353.67526343,   0.        ,  14.62909589,  34.36120139,
#         16.48675036,  43.95629574,  39.62137677,   6.63857295,
#          0.        ])
#          Creating SHAP plots for Improved FT-Transformer...
#          ✓ SHAP summary plot saved
#          ✓ SHAP importance plot saved
# 2025-07-27 10:16:34,961 - INFO - SHAP analysis completed for Improved FT-Transformer with 20 samples
# 2025-07-27 10:16:35,091 - WARNING - Error explaining instance 0: 'hr > 0.79'
#       🍋 Performing LIME analysis...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:35,238 - WARNING - Error explaining instance 1: 'hr > 0.79'
# 2025-07-27 10:16:35,385 - WARNING - Error explaining instance 2: 'hr <= -0.80'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:35,542 - WARNING - Error explaining instance 3: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:16:35,683 - WARNING - Error explaining instance 4: 'hr <= -0.80'
# 2025-07-27 10:16:35,685 - INFO - LIME analysis completed for 5 instances
# 2025-07-27 10:16:35,691 - INFO - Completed explainability analysis for Improved FT-Transformer
# 🔬 calling predict in wrapper
# 💾 Intermediate results saved to './Section3_Explainability/Improved FT-Transformer_explainability_results.pkl'
# 💾 Intermediate results saved to 'bike_sharing_improved_ft_explanations.pkl'
# ✅ Improved FT-Transformer explainability analysis completed
#
# 🎯 Top 10 Most Important Features (Improved FT-Transformer - Permutation):
#     1. hr: 1.6106
#     2. workingday: 0.2607
#     3. yr: 0.0725
#     4. temp: 0.0660
#     5. weathersit: 0.0389
#     6. atemp: 0.0384
#     7. hum: 0.0367
#     8. instant: 0.0348
#     9. season: 0.0323
#    10. weekday: 0.0301
#
# GPU memory allocated: 15.37 MB
# GPU memory cached: 34.00 MB

# %%
# Analyze SAINT explainability
saint_results = analyze_saint_explainability(
    models_to_analyze, explainer, X_train_scaled, X_test_scaled, 
    y_train, y_test, feature_names, device, max_samples=300
)
if saint_results:
    intermediate_results['saint_explanations'] = saint_results
# Out:
# 2025-07-27 10:17:07,253 - INFO - Starting explainability analysis for SAINT
# 2025-07-27 10:17:07,426 - INFO - Baseline metrics calculated - R²: 0.9307, RMSE: 46.8501
# ============================================================
# SAINT EXPLAINABILITY ANALYSIS
# ============================================================
#
# 🔍 Analyzing SAINT explainability...
# 🔬 calling predict in wrapper
#       📊 Calculating permutation importance...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:17:09,302 - INFO - Permutation importance calculated using 300 samples
#       🎯 Performing SHAP analysis...
#          Using CPU for SHAP with 50 samples
#          Using CPU-based KernelExplainer for neural network
# 🔬 calling predict in wrapper
#   0%|          | 0/20 [00:00<?, ?it/s]
# 2025-07-27 10:17:09,495 - INFO - num_full_subsets = 3
# 2025-07-27 10:17:09,496 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:17:09,496 - INFO - num_paired_subset_sizes = 6
# 🔬 calling predict in wrapper
# 2025-07-27 10:17:09,523 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 2025-07-27 10:17:14,275 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 10:17:14,276 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:17:14,282 - INFO - phi = array([ 17.89187979,  15.56259654,  38.79445344,   6.64887111,
#          0.        ,   0.        ,   0.        , -53.76097998,
#         13.44193281,  36.26744936,  18.92281873,  22.17619899,
#          5.50872218])
# 2025-07-27 10:17:14,322 - INFO - num_full_subsets = 3
# 2025-07-27 10:17:14,324 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:17:14,327 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:17:14,379 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:17:19,144 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:17:19,145 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:17:19,150 - INFO - phi = array([-15.53350969,   0.        , -34.95201436,   9.26746954,
#         29.21957651,   2.20674941,   5.39714205,   0.        ,
#          0.        ,   7.52103871,   8.94082791,   6.12014897,
#          3.60092556])
# 2025-07-27 10:17:19,172 - INFO - num_full_subsets = 3
# 2025-07-27 10:17:19,174 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:17:19,175 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:17:19,224 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:17
- INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:18:37,759 - INFO - np.sum(self.kernelWeights) = 1.0000000000000002
# 2025-07-27 10:18:37,766 - INFO - phi = array([  -9.83034115,  -10.11837456,  -10.27935763,    0.        ,
#        -150.94291166,    0.        ,    0.        ,   -8.79401393,
#           8.06851798,  -16.19300899,   -8.39111554,    9.90676692,
#           5.96811871])
# 2025-07-27 10:18:37,805 - INFO - num_full_subsets = 3
# 2025-07-27 10:18:37,807 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:18:37,810 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:18:37,862 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:18:42,698 - INFO - np.sum(w_aug) = 12.999999999999998
# 2025-07-27 10:18:42,699 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 10:18:42,706 - INFO - phi = array([ 10.37782261,  28.67864705, -27.27019171,   3.37282741,
#          0.        ,   8.72773131,   2.91716614, -27.47630912,
#         17.06848427,  -7.1865196 ,   0.        ,  24.83304499,
#          0.        ])
# 2025-07-27 10:18:42,743 - INFO - num_full_subsets = 3
# 2025-07-27 10:18:42,745 - INFO - remaining_weight_vector = array([0.3626943 , 0.32642487, 0.31088083])
# 2025-07-27 10:18:42,746 - INFO - num_paired_subset_sizes = 6
# 2025-07-27 10:18:42,797 - INFO - weight_left = 0.32084025993652715
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:18:47,640 - INFO - np.sum(w_aug) = 12.999999999999996
# 2025-07-27 10:18:47,641 - INFO - np.sum(self.kernelWeights) = 1.0
# 2025-07-27 10:18:47,647 - INFO - phi = array([   0.        ,    9.65678044,  -15.83523638,    4.19544265,
#        -185.2201708 ,    3.25524762,    0.        ,  -12.0100635 ,
#           9.63975419,   17.43902518,   12.35300199,    0.        ,
#           6.04630081])
#          Creating SHAP plots for SAINT...
#          ✓ SHAP summary plot saved
# 2025-07-27 10:18:48,484 - INFO - SHAP analysis completed for SAINT with 20 samples
#          ✓ SHAP importance plot saved
#       🍋 Performing LIME analysis...
# 🔬 calling predict in wrapper
# 2025-07-27 10:18:48,770 - WARNING - Error explaining instance 0: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:18:49,071 - WARNING - Error explaining instance 1: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:18:49,372 - WARNING - Error explaining instance 2: 'hr <= -0.80'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:18:49,674 - WARNING - Error explaining instance 3: 'hr > 0.79'
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 2025-07-27 10:18:49,977 - WARNING - Error explaining instance 4: 'hr <= -0.80'
# 2025-07-27 10:18:49,978 - INFO - LIME analysis completed for 5 instances
# 2025-07-27 10:18:49,983 - INFO - Completed explainability analysis for SAINT
# 🔬 calling predict in wrapper
# 💾 Intermediate results saved to './Section3_Explainability/SAINT_explainability_results.pkl'
# 💾 Intermediate results saved to 'bike_sharing_saint_explanations.pkl'
# ✅ SAINT explainability analysis completed
#
# 🎯 Top 10 Most Important Features (SAINT - Permutation):
#     1. hr: 1.4751
#     2. workingday: 0.3905
#     3. yr: 0.1090
#     4. temp: 0.0719
#     5. hum: 0.0489
#     6. season: 0.0407
#     7. weathersit: 0.0401
#     8. atemp: 0.0301
#     9. weekday: 0.0169
#    10. instant: 0.0121
#
# GPU memory allocated: 15.37 MB
# GPU memory cached: 34.00 MB

# %% [markdown]
# ### 4.5 Cross-Model Feature Importance Comparison

# %%
# Compare feature importance across models
importance_comparison, avg_importance = perform_cross_model_comparison(explainer)

if importance_comparison is not None:
    print("\n📊 Feature importance comparison completed successfully!")
    print(f"Top 3 features: {list(avg_importance.head(3).index)}")
else:
    print("⚠️ No feature importance data available for comparison")
# Out:
# ============================================================
# CROSS-MODEL FEATURE IMPORTANCE COMPARISON
# ============================================================
#
# GPU memory allocated: 15.37 MB
# GPU memory cached: 34.00 MB
#
# 🔄 Comparing feature importance across models...
# 2025-07-27 10:19:00,880 - INFO - Feature importance comparison completed
# 📊 Feature Importance Comparison Table:
#             XGBoost_permutation  XGBoost_builtin  XGBoost_shap  Improved FT-Transformer_permutation  Improved FT-Transformer_shap  SAINT_permutation  SAINT_shap
# instant                  0.0768           0.0436        0.1162                               0.0153                        0.0437             0.0054      0.0393
# season                   0.0055           0.0523        0.0303                               0.0142                        0.0559             0.0181      0.0675
# yr                       0.0112           0.1725        0.0527                               0.0320                        0.0968             0.0485      0.1268
# mnth                     0.0024           0.0137        0.0090                               0.0125                        0.0308             0.0032      0.0319
# hr                       0.7141           0.2062        0.4224                               0.7096                        0.4177             0.6558      0.3169
# holiday                  0.0002           0.0102        0.0019                               0.0053                        0.0021             0.0010      0.0184
# weekday                  0.0115           0.0158        0.0267                               0.0133                        0.0244             0.0075      0.0325
# workingday               0.0972           0.2823        0.0825                               0.1149                        0.0909             0.1736      0.0814
# weathersit               0.0098           0.0314        0.0340                               0.0171                        0.0329             0.0178      0.0394
# temp                     0.0377           0.0813        0.1153                               0.0291                        0.0831             0.0320      0.1032
# atemp                    0.0122           0.0433        0.0442                               0.0169                        0.0631             0.0134      0.0627
# hum                      0.0212           0.0399        0.0555                               0.0162                        0.0517             0.0217      0.0606
# windspeed                0.0003           0.0074        0.0095                               0.0038                        0.0068             0.0021      0.0195
#
# 💾 Feature importance comparison saved to './Section3_Explainability/bike_sharing_feature_importance_comparison.csv'
#
# 🎯 FEATURE IMPORTANCE CONSENSUS:
#
# Top 10 Most Important Features (Average Across All Methods):
#     1. hr: 0.4918
#     2. workingday: 0.1318
#     3. yr: 0.0772
#     4. temp: 0.0688
#     5. instant: 0.0486
#     6. hum: 0.0381
#     7. atemp: 0.0365
#     8. season: 0.0348
#     9. weathersit: 0.0261
#    10. weekday: 0.0188
#
# 🔗 Feature Importance Correlation Between Methods:
#                                      XGBoost_permutation  XGBoost_builtin  XGBoost_shap  Improved FT-Transformer_permutation  Improved FT-Transformer_shap  SAINT_permutation  SAINT_shap
# XGBoost_permutation                                1.000            0.534         0.972                                0.995                         0.970              0.984       0.919
# XGBoost_builtin                                    0.534            1.000         0.558                                0.564                         0.626              0.646       0.660
# XGBoost_shap                                       0.972            0.558         1.000                                0.953                         0.966              0.943       0.935
# Improved FT-Transformer_permutation                0.995            0.564         0.953                                1.000                         0.976              0.994       0.931
# Improved FT-Transformer_shap                       0.970            0.626         0.966                                0.976                         1.000              0.974       0.984
# SAINT_permutation                                  0.984            0.646         0.943                                0.994                         0.974              1.000       0.934
# SAINT_shap                                         0.919            0.660         0.935                                0.931                         0.984              0.934       1.000
#
# 📊 Feature importance comparison completed successfully!
# Top 3 features: ['hr', 'workingday', 'yr']

# %% [markdown]
# ### 4.6 Generate Detailed Reports

# %%
# Generate detailed explanation reports for each model
generate_explanation_reports(explainer)
# Out:
# ============================================================
# DETAILED EXPLANATION REPORTS
# ============================================================
# Available models for reporting: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
#
# ==================================================
# EXPLANATION REPORT: XGBoost
# ==================================================
#
# 📋 EXPLANATION REPORT: XGBoost
# ============================================================
#
# 📊 Baseline Performance:
#    R² Score: 0.9546
#    RMSE: 37.9232
#    MAE: 23.8845
#    MAPE: 0.45%
#    Training Time: 0.154s
#    Inference Time: 0.005s
#
# 🎯 Top 10 Most Important Features (Permutation):
#     1. hr: 1.3948
#     2. workingday: 0.1899
#     3. instant: 0.1500
#     4. temp: 0.0736
#     5. hum: 0.0413
#     6. atemp: 0.0238
#     7. weekday: 0.0225
#     8. yr: 0.0219
#     9. weathersit: 0.0192
#    10. season: 0.0107
#
# 🏗️ Top 10 Most Important Features (Built-in):
#     1. workingday: 0.2823
#     2. hr: 0.2062
#     3. yr: 0.1725
#     4. temp: 0.0813
#     5. season: 0.0523
#     6. instant: 0.0436
#     7. atemp: 0.0433
#     8. hum: 0.0399
#     9. weathersit: 0.0314
#    10. weekday: 0.0158
#
# 🎯 SHAP Analysis:
#    Explainer Type: TreeExplainer
#    Samples Analyzed: 200
#    Top 5 SHAP Features:
#       1. hr: 104.1481
#       2. instant: 28.6591
#       3. temp: 28.4303
#       4. workingday: 20.3394
#       5. hum: 13.6896
#
# 🍋 LIME Analysis:
#    Instances Explained: 0
#    Top 5 LIME Features:
#
# ✅ Report completed for XGBoost
#
# ----------------------------------------
#
# ==================================================
# EXPLANATION REPORT: Improved FT-Transformer
# ==================================================
#
# 📋 EXPLANATION REPORT: Improved FT-Transformer
# ============================================================
#
# 📊 Baseline Performance:
#    R² Score: 0.9385
#    RMSE: 44.1403
#    MAE: 27.9566
#    MAPE: 0.39%
#    Training Time: 0.000s
#    Inference Time: 0.151s
#
# 🎯 Top 10 Most Important Features (Permutation):
#     1. hr: 1.6106
#     2. workingday: 0.2607
#     3. yr: 0.0725
#     4. temp: 0.0660
#     5. weathersit: 0.0389
#     6. atemp: 0.0384
#     7. hum: 0.0367
#     8. instant: 0.0348
#     9. season: 0.0323
#    10. weekday: 0.0301
#
# 🎯 SHAP Analysis:
#    Explainer Type: KernelExplainer_CPU
#    Samples Analyzed: 20
#    Top 5 SHAP Features:
#       1. hr: 112.6569
#       2. yr: 26.1100
#       3. workingday: 24.5133
#       4. temp: 22.4074
#       5. atemp: 17.0300
#
# 🍋 LIME Analysis:
#    Instances Explained: 0
#    Top 5 LIME Features:
#
# ✅ Report completed for Improved FT-Transformer
#
# ----------------------------------------
#
# ==================================================
# EXPLANATION REPORT: SAINT
# ==================================================
#
# 📋 EXPLANATION REPORT: SAINT
# ============================================================
#
# 📊 Baseline Performance:
#    R² Score: 0.9307
#    RMSE: 46.8501
#    MAE: 29.7511
#    MAPE: 0.34%
#    Training Time: 0.000s
#    Inference Time: 0.168s
#
# 🎯 Top 10 Most Important Features (Permutation):
#     1. hr: 1.4751
#     2. workingday: 0.3905
#     3. yr: 0.1090
#     4. temp: 0.0719
#     5. hum: 0.0489
#     6. season: 0.0407
#     7. weathersit: 0.0401
#     8. atemp: 0.0301
#     9. weekday: 0.0169
#    10. instant: 0.0121
#
# 🎯 SHAP Analysis:
#    Explainer Type: KernelExplainer_CPU
#    Samples Analyzed: 20
#    Top 5 SHAP Features:
#       1. hr: 77.2401
#       2. yr: 30.9000
#       3. temp: 25.1563
#       4. workingday: 19.8296
#       5. season: 16.4474
#
# 🍋 LIME Analysis:
#    Instances Explained: 0
#    Top 5 LIME Features:
#
# ✅ Report completed for SAINT
#
# ----------------------------------------

# %% [markdown]
# ### 4.7 Business Insights

# %%
# Generate business insights
available_models = list(explainer.explanations.keys())
generate_business_insights(importance_comparison, avg_importance, available_models)
# Out:
# ================================================================================
# BUSINESS INSIGHTS FOR BIKE SHARING DEMAND PREDICTION
# ================================================================================
#
# 💼 KEY BUSINESS INSIGHTS:
#
# Top 5 Most Critical Features for Bike Demand Prediction:
#    1. hr: 0.4918
#       💡 Business Impact: Hour of day indicates commuting patterns and peak usage times
#    2. workingday: 0.1318
#       💡 Business Impact: Working day status determines commuting demand patterns
#    3. yr: 0.0772
#       💡 Business Impact: Year-over-year growth and system maturity effects
#    4. temp: 0.0688
#       💡 Business Impact: Temperature directly affects cycling comfort and demand
#    5. instant: 0.0486
#       💡 Business Impact: This feature significantly influences bike sharing demand
#
# 🔍 MODEL INTERPRETABILITY INSIGHTS:
#
# 1. XGBoost:
#    - Most interpretable with built-in feature importance
#    - Tree-based structure allows for clear decision paths
#    - SHAP values provide detailed feature contributions to predictions
#    - Best for understanding individual prediction reasoning
#
# 2. Improved FT-Transformer:
#    - Attention-based architecture for tabular data
#    - Feature interactions through attention mechanisms
#    - Moderate interpretability through attention weights
#    - Good balance of performance and explainability for regression
#
# 3. SAINT:
#    - Self-attention and intersample attention mechanisms
#    - Complex feature interactions modeling
#    - Limited interpretability due to attention complexity
#    - Requires permutation importance for feature understanding
#
# 📋 ACTIONABLE BUSINESS RECOMMENDATIONS:
#
# 🎯 For Operations Teams:
#    • Monitor weather forecasts for demand planning
#    • Adjust bike availability based on temperature and humidity
#    • Prepare for seasonal demand variations
#    • Optimize bike distribution for peak hours
#
# 🎯 For Marketing Teams:
#    • Target campaigns based on weather-dependent usage patterns
#    • Promote usage during optimal weather conditions
#    • Develop seasonal membership strategies
#    • Focus on commuter vs recreational user segments
#
# 🎯 For Data Science Teams:
#    • Use XGBoost for interpretable demand forecasting
#    • Implement SHAP explanations for stakeholder communication
#    • Monitor feature importance drift over time
#    • A/B test weather-based interventions

# %% [markdown]
# ### 4.8 Ablation Studies

# %%
print(X_train_scaled.shape)
print(X_test_scaled.shape)
print(y_train.shape)
print(y_test.shape)
print(X_train_scaled.shape[1])
# Out:
# (11122, 13)
# (3476, 13)
# (11122,)
# (3476,)
# 13

# %%
# Run enhanced ablation studies
import torch, gc
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
gc.collect()
torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()
torch.cuda.reset_accumulated_memory_stats()


# Instead of passing all models
# model_names = ['XGBoost', 'FT-Transformer', 'SAINT']
print(torch.cuda.memory_summary())
ablation_analyzer, ablation_results, ablation_summary_df = run_ablation_studies(
    models_to_analyze, X_train_scaled, X_test_scaled, y_train, y_test, feature_names
)

if ablation_results:
    print("\n✅ Ablation studies completed successfully!")
    print(f"Models analyzed: {list(ablation_results.keys())}")
else:
    print("⚠️ Ablation studies encountered issues")
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   7414 KiB |   7414 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   7414 KiB |   7414 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Active memory         |   7414 KiB |   7414 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   7414 KiB |   7414 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Requested memory      |   7407 KiB |   7407 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   7407 KiB |   7407 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  14336 KiB |  14336 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |  14336 KiB |  14336 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |   6922 KiB |   6922 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   6922 KiB |   6922 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Allocations           |     154    |     154    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |     154    |     154    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     154    |     154    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |     154    |     154    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       7    |       7    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       7    |       7    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       8    |       8    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       8    |       8    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
#
# ================================================================================
# ENHANCED ABLATION STUDIES
# ================================================================================
# Running ablation studies for: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# 🔬 COMPREHENSIVE ABLATION STUDY
# ================================================================================
#
# 📊 Running ablation studies for XGBoost...
#         running ablation studies for XGBoost
#       🔍 Feature ablation study...
#       📊 Data size ablation study...
#       🔊 Noise robustness study...
#    🧪 Running XGBoost-specific ablations...
#         🎛️ Hyperparameter ablation...
#         🌳 Tree complexity ablation...
#         🛡️ Regularization ablation...
#         🎯 Feature importance analysis...
# 💾 XGBoost ablation results saved to 'bike_sharing_ablation_XGBoost.pkl'
#
# GPU memory allocated: 7.24 MB
# GPU memory cached: 14.00 MB
#
# 📊 Running ablation studies for Improved FT-Transformer...
# 🔬 Creating pytorchwrapper for Improved FT-Transformer
#         running ablation studies for Improved FT-Transformer
# 🔬 calling predict in wrapper
#       🔍 Feature ablation study...
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 15.37 MB
# GPU memory cached: 34.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.376263, LR: 0.000452
#           Epoch 20/50, Loss: 0.309072, LR: 0.000327
#           Epoch 30/50, Loss: 0.264606, LR: 0.000173
#           Epoch 40/50, Loss: 0.250877, LR: 0.000048
#           Epoch 50/50, Loss: 0.245737, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.6129
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.368601, LR: 0.000452
#           Epoch 20/50, Loss: 0.293196, LR: 0.000327
#           Epoch 30/50, Loss: 0.272313, LR: 0.000173
#           Epoch 40/50, Loss: 0.260152, LR: 0.000048
#           Epoch 50/50, Loss: 0.255987, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.
LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5557
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.441040, LR: 0.000452
#           Epoch 20/50, Loss: 0.402587, LR: 0.000327
#           Epoch 30/50, Loss: 0.390931, LR: 0.000173
#           Epoch 40/50, Loss: 0.386925, LR: 0.000048
#           Epoch 50/50, Loss: 0.385543, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.3495
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.407381, LR: 0.000452
#           Epoch 20/50, Loss: 0.325964, LR: 0.000327
#           Epoch 30/50, Loss: 0.293343, LR: 0.000173
#           Epoch 40/50, Loss: 0.272977, LR: 0.000048
#           Epoch 50/50, Loss: 0.270796, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5867
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.370649, LR: 0.000452
#           Epoch 20/50, Loss: 0.301691, LR: 0.000327
#           Epoch 30/50, Loss: 0.275375, LR: 0.000173
#           Epoch 40/50, Loss: 0.266702, LR: 0.000048
#           Epoch 50/50, Loss: 0.266930, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5353
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.409188, LR: 0.000452
#           Epoch 20/50, Loss: 0.329392, LR: 0.000327
#           Epoch 30/50, Loss: 0.281494, LR: 0.000173
#           Epoch 40/50, Loss: 0.266521, LR: 0.000048
#           Epoch 50/50, Loss: 0.262003, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5831
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.384845, LR: 0.000452
#           Epoch 20/50, Loss: 0.306390, LR: 0.000327
#           Epoch 30/50, Loss: 0.278780, LR: 0.000173
#           Epoch 40/50, Loss: 0.268115, LR: 0.000048
#           Epoch 50/50, Loss: 0.264051, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5453
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.398496, LR: 0.000452
#           Epoch 20/50, Loss: 0.324299, LR: 0.000327
#           Epoch 30/50, Loss: 0.281424, LR: 0.000173
#           Epoch 40/50, Loss: 0.262791, LR: 0.000048
#           Epoch 50/50, Loss: 0.256633, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5799
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.383442, LR: 0.000452
#           Epoch 20/50, Loss: 0.321116, LR: 0.000327
#           Epoch 30/50, Loss: 0.286263, LR: 0.000173
#           Epoch 40/50, Loss: 0.271970, LR: 0.000048
#           Epoch 50/50, Loss: 0.270668, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5725
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.377674, LR: 0.000452
#           Epoch 20/50, Loss: 0.313895, LR: 0.000327
#           Epoch 30/50, Loss: 0.279830, LR: 0.000173
#           Epoch 40/50, Loss: 0.268939, LR: 0.000048
#           Epoch 50/50, Loss: 0.267866, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5499
#           🧹 Clearing memory before retraining Improved FT-Transformer...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔧 Applying target scaling for proper training...
#           🚀 Training FT-Transformer with 12 features for 50 epochs...
#           Epoch 10/50, Loss: 0.402542, LR: 0.000452
#           Epoch 20/50, Loss: 0.329247, LR: 0.000327
#           Epoch 30/50, Loss: 0.291501, LR: 0.000173
#           Epoch 40/50, Loss: 0.271946, LR: 0.000048
#           Epoch 50/50, Loss: 0.266115, LR: 0.000000
#           ✅ FT-Transformer retraining completed. R² = 0.5593
#       📊 Data size ablation study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#       🔊 Noise robustness study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#    🧪 Running FT-Transformer-specific ablations...
#         🏗️ Architecture ablation...
#         📚 Training hyperparameter ablation...
#         💻 Device performance ablation...
#         📦 Batch size efficiency ablation...
# 💾 Improved FT-Transformer ablation results saved to 'bike_sharing_ablation_Improved_FT_Transformer.pkl'
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#
# 📊 Running ablation studies for SAINT...
# 🔬 Creating pytorchwrapper for SAINT
#         running ablation studies for SAINT
# 🔬 calling predict in wrapper
#       🔍 Feature ablation study...
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9877
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0318
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8970
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1927
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0203
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8972
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0622
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0490
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1437
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0346
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9694
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0697
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0391
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.7685
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0684
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9600
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0146
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9830
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0293
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
# ...
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8647
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0418
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1819
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0324
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9052
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8626
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1483
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1088
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1412
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2447
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2041
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0783
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8991
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1137
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1306
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1177
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0499
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8876
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0730
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9781
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0261
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1957
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0173
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0115
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.07 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9322
#       📊 Data size ablation study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#       🔊 Noise robustness study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#    🧪 Running SAINT-specific ablations...
#         🏗️ Architecture ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         📚 Training hyperparameter ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         💻 Device performance ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         🎯 Attention mechanism ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 💾 SAINT ablation results saved to 'bike_sharing_ablation_SAINT.pkl'
#
# GPU memory allocated: 23.49 MB
# GPU memory cached: 70.00 MB
#
# 🔄 Running comparative analysis...
#       🎯 Comparing feature importance...
#       🛡️ Comparing model robustness...
#       ⚡ Comparing computational efficiency...
# 📋 COMPREHENSIVE ABLATION STUDY REPORT
# ================================================================================
#
# 📊 BASELINE PERFORMANCE SUMMARY
# --------------------------------------------------
#
# XGBoost:
#   R² Score: 0.9546
#   RMSE: 37.9232
#   MAE: 23.8845
#   MSE: 1438.1665
#   MAPE: 0.45%
#   Explained Variance: 0.9546
#   Train Time: 0.182s
#   Inference Time: 0.007s
#
# Improved FT-Transformer:
#   R² Score: -1.0704
#   RMSE: 256.0469
#   MAE: 184.8185
#   MSE: 65560.0103
#   MAPE: 1.02%
#   Explained Variance: 0.0083
#   Train Time: 0.000s
#   Inference Time: 0.141s
#
# SAINT:
#   R² Score: 0.9307
#   RMSE: 46.8501
#   MAE: 29.7511
#   MSE: 2194.9274
#   MAPE: 0.34%
#   Explained Variance: 0.9309
#   Train Time: 0.000s
#   Inference Time: 0.161s
#
# 🎯 FEATURE IMPORTANCE INSIGHTS
# --------------------------------------------------
#
# XGBoost - Top 3 Most Important Features:
#   1. hr: R² drop = 0.4859 (50.9% relative importance)
#   2. weekday: R² drop = 0.0114 (1.2% relative importance)
#   3. workingday: R² drop = 0.0079 (0.8% relative importance)
#
# Improved FT-Transformer - Top 3 Most Important Features:
#   1. hr: R² drop = -1.4239 (0.0% relative importance)
#   2. atemp: R² drop = -1.5834 (0.0% relative importance)
#   3. hum: R² drop = -1.6212 (0.0% relative importance)
#
# SAINT - Top 3 Most Important Features:
#   1. mnth: R² drop = 2.1234 (228.2% relative importance)
#   2. weathersit: R² drop = 2.0744 (222.9% relative importance)
#   3. hum: R² drop = 2.0004 (214.9% relative importance)
#
# 🔬 MODEL-SPECIFIC INSIGHTS
# --------------------------------------------------
#
# XGBoost:
#
# Improved FT-Transformer:
#
# SAINT:
#
# 🛡️ ROBUSTNESS RANKING
# --------------------------------------------------
#    1. SAINT: 0.791
#    2. XGBoost: 0.620
#    3. Improved FT-Transformer: 0.000
#
# ⚡ EFFICIENCY RANKING
# --------------------------------------------------
#
# Fastest Training:
#    1. SAINT: 0.000s
#    2. Improved FT-Transformer: 0.000s
#    3. XGBoost: 0.182s
#
# Fastest Inference:
#    1. XGBoost: 0.007s
#    2. Improved FT-Transformer: 0.141s
#    3. SAINT: 0.161s
#
# 🎯 FINAL RECOMMENDATIONS
# --------------------------------------------------
#
# 1. Best Overall Performance: [Based on R² scores and RMSE]
# 2. Most Robust Model: [Based on noise robustness analysis]
# 3. Most Efficient Model: [Based on training/inference time]
# 4. Most Feature-Dependent: [Based on feature ablation results]
# 5. Best for Production: [Balanced performance, efficiency, and robustness]
#
# ✅ Comprehensive ablation study analysis complete!
# 💾 Comprehensive ablation results saved to 'bike_sharing_section5_ablation_results.pkl'
# 📋 Contains results for 3 models
#
# ✅ Ablation studies completed successfully!
#
# 📊 Ablation Study Summary:
#                   Model  R2_Score       RMSE        MAE          MSE     MAPE  Explained_Variance   Train_Time  Inference_Time Most_Important_Feature  Feature_Importance_Score  Robustness_Score
#                 XGBoost  0.954582  37.923165  23.884511  1438.166460 0.452483            0.954586 1.821918e-01        0.006615                     hr                  0.509018          0.620352
# Improved FT-Transformer -1.070398 256.046891 184.818495 65560.010250 1.021158            0.008314 9.536743e-07        0.140971                     hr                  0.000000          0.000000
#                   SAINT  0.930684  46.850052  29.751069  2194.927356 0.342723            0.930898 7.152557e-07        0.161213                   mnth                  2.281519          0.790968
# ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# [0.1821918487548828, 9.5367431640625e-07, 7.152557373046875e-07]
# ✅ Ablation studies completed successfully!
# Models analyzed: ['XGBoost', 'Improved FT-Transformer', 'SAINT', 'comparative_analysis']

# %%
#import torch, gc
#import os
#os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
#gc.collect()
#torch.cuda.empty_cache()
#torch.cuda.reset_peak_memory_stats()
#torch.cuda.reset_accumulated_memory_stats()


# Instead of passing all models
# model_names = ['XGBoost', 'FT-Transformer', 'SAINT']
#print(torch.cuda.memory_summary())

# Pass only SAINT
#saint_model = models_to_analyze['SAINT']
#temp = {"SAINT":saint_model}
#analyzer, results = run_ablation_studies(
#    temp, 
#    X_train_scaled, X_test_scaled, y_train, y_test, feature_names
#)
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   7074 KiB |   7074 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   7074 KiB |   7074 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Active memory         |   7074 KiB |   7074 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   7074 KiB |   7074 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Requested memory      |   7073 KiB |   7073 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   7073 KiB |   7073 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |  10240 KiB |  10240 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |  10240 KiB |  10240 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |   3165 KiB |   3165 KiB |      0 B   |      0 B   |
# |       from large pool |      0 KiB |      0 KiB |      0 B   |      0 B   |
# |       from small pool |   3165 KiB |   3165 KiB |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Allocations           |     117    |     117    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |     117    |     117    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     117    |     117    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |     117    |     117    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       5    |       5    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       5    |       5    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       4    |       4    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       4    |       4    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|
#
#
# ================================================================================
# ENHANCED ABLATION STUDIES
# ================================================================================
# Running ablation studies for: ['SAINT']
# 🔬 COMPREHENSIVE ABLATION STUDY
# ================================================================================
#
# 📊 Running ablation studies for SAINT...
# 🔬 Creating pytorchwrapper for SAINT
#         running ablation studies for SAINT
#         calling model.fit
#         done calling model.fit
#         calling model.predict
# 🔬 calling predict in wrapper
#         done calling model.predict
#       🔍 Feature ablation study...
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 15.03 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.01 GB
#    Cached: 0.03 GB
#    Free: 14.55 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2297
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0281
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0437
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9794
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2537
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8831
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0964
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9958
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0475
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2166
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0924
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9513
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0151
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0685
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0444
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0434
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2148
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9552
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0572
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1167
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9403
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9947
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9641
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0594
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2426
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0729
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9979
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9325
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0821
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8878
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 12 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9579
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9770
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.1342
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2111
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0594
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9028
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8172
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8889
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9635
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9945
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9920
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.8228
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 11 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2010
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0298
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0170
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9610
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0984
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.2220
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0088
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9182
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0978
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0325
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -0.9813
#           🧹 Clearing memory before retraining SAINT...
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#           🔄 Retraining SAINT model with 10 features...
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
# 🧹 After aggressive clearing:
#    Total GPU Memory: 14.56 GB
#    Allocated: 0.02 GB
#    Cached: 0.03 GB
#    Free: 14.54 GB
#           ✅ SAINT retraining completed. R² = -1.0770
#       📊 Data size ablation study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#       🔊 Noise robustness study...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#    🧪 Running SAINT-specific ablations...
#         🏗️ Architecture ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         📚 Training hyperparameter ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         💻 Device performance ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
#         🎯 Attention mechanism ablation...
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 🔬 calling predict in wrapper
# 💾 SAINT ablation results saved to 'bike_sharing_ablation_SAINT.pkl'
#
# GPU memory allocated: 23.16 MB
# GPU memory cached: 30.00 MB
#
# 🔄 Running comparative analysis...
#       🎯 Comparing feature importance...
#       🛡️ Comparing model robustness...
#       ⚡ Comparing computational efficiency...
# 📋 COMPREHENSIVE ABLATION STUDY REPORT
# ================================================================================
#
# 📊 BASELINE PERFORMANCE SUMMARY
# --------------------------------------------------
#
# SAINT:
#   R² Score: 0.9307
#   RMSE: 46.8501
#   MAE: 29.7511
#   MSE: 2194.9274
#   MAPE: 0.34%
#   Explained Variance: 0.9309
#   Train Time: 0.000s
#   Inference Time: 0.287s
#
# 🎯 FEATURE IMPORTANCE INSIGHTS
# --------------------------------------------------
#
# SAINT - Top 3 Most Important Features:
#   1. hr: R² drop = 2.1844 (234.7% relative importance)
#   2. instant: R² drop = 2.1603 (232.1% relative importance)
#   3. temp: R² drop = 2.1473 (230.7% relative importance)
#
# 🔬 MODEL-SPECIFIC INSIGHTS
# --------------------------------------------------
#
# SAINT:
#
# 🛡️ ROBUSTNESS RANKING
# --------------------------------------------------
#    1. SAINT: 0.783
#
# ⚡ EFFICIENCY RANKING
# --------------------------------------------------
#
# Fastest Training:
#    1. SAINT: 0.000s
#
# Fastest Inference:
#    1. SAINT: 0.287s
#
# 🎯 FINAL RECOMMENDATIONS
# --------------------------------------------------
#
# 1. Best Overall Performance: [Based on R² scores and RMSE]
# 2. Most Robust Model: [Based on noise robustness analysis]
# 3. Most Efficient Model: [Based on training/inference time]
# 4. Most Feature-Dependent: [Based on feature ablation results]
# 5. Best for Production: [Balanced performance, efficiency, and robustness]
#
# ✅ Comprehensive ablation study analysis complete!
# 💾 Comprehensive ablation results saved to 'bike_sharing_section5_ablation_results.pkl'
# 📋 Contains results for 1 models
#
# ✅ Ablation studies completed successfully!
#
# 📊 Ablation Study Summary:
# Model  R2_Score      RMSE       MAE         MSE     MAPE  Explained_Variance  Train_Time  Inference_Time Most_Important_Feature  Feature_Importance_Score  Robustness_Score
# SAINT  0.930684 46.850052 29.751069 2194.927356 0.342723            0.930898    0.000024        0.286518                     hr                  2.347089           0.78258
# ⚠️ Error in ablation studies: 'f1'
# Continuing with explainability analysis...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 17
#      15 saint_model = models_to_analyze['SAINT']
#      16 temp = {"SAINT":saint_model}
# ---> 17 analyzer, results = run_ablation_studies(
#      18     temp,
#      19     X_train_scaled, X_test_scaled, y_train, y_test, feature_names
#      20 )
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ### 4.9 Generate Analysis Summary

# %%
print(ablation_analyzer.results['Improved FT-Transformer']['baseline'])
# Out:
# {'r2_score': -1.0703981879017443, 'rmse': 256.04689072543596, 'mae': 184.81849473703468, 'mse': 65560.01025016335, 'explained_variance': 0.008314342749546899, 'train_time': 2.5510787963867188e-05, 'inference_time': 0.14417028427124023, 'n_train_samples': 11122, 'n_test_samples': 3476, 'mape': 1.0211579378073803}

# %%
# Generate comprehensive analysis summary
generate_analysis_summary(comparison_df, importance_comparison, avg_importance, ablation_results)
# Out:
# ================================================================================
# EXPLAINABILITY ANALYSIS SUMMARY
# ================================================================================
#
# 🏆 MODEL PERFORMANCE RECAP:
#    R²_Score     RMSE      MAE    MAPE
# 0    0.9546  37.9232  23.8845  0.4525
# 1    0.9385  44.1403  27.9566  0.3941
# 2    0.9316  46.5453  29.5580  0.3389
#
# 🎯 KEY FEATURE IMPORTANCE INSIGHTS:
#
# Most Important Features for Bike Sharing Demand Prediction:
#    1. hr: 0.4918
#    2. workingday: 0.1318
#    3. yr: 0.0772
#    4. temp: 0.0688
#    5. instant: 0.0486
#
# Feature Importance Consensus: 13 features analyzed
# Top feature: hr (0.4918)
#
# 📋 KEY FINDINGS:
#
# • Bike sharing demand is primarily driven by weather and temporal factors
# • Temperature and humidity are consistently the most important features
# • Hour of day and seasonal patterns are strong indicators of usage
# • Different models may prioritize different feature combinations
# • Feature importance consensus helps identify robust predictors
# • Model interpretability varies significantly across architectures
# • XGBoost provides the best balance of performance and interpretability
#
# ✅ Section 3 completed successfully!
# 📊 Comprehensive explainability analysis finished
# 📁 All results and visualizations saved
# 🎯 Ready for deployment and business implementation

# %% [markdown]
# ### 4.10 Save Final Results

# %%
# Save final results
results_file = save_final_results(
    explainer, importance_comparison, avg_importance, feature_names, 
    models_to_analyze, ablation_results
)

print(f"\n🎉 Analysis complete! Results saved to: {results_file}")
# Out:
# 2025-07-27 10:29:31,685 - INFO - Comprehensive results saved to ./Section3_Explainability/comprehensive_explainability_results.pkl
# 💾 Section 3 explainability results saved to 'bike_sharing_section3_explainability.pkl'
# 📋 This file contains all explainability analysis results
# 💾 Intermediate results saved to './Section3_Explainability/comprehensive_explainability_results.pkl'
#
# 🎉 Bike Sharing Explainability Analysis Complete!
#
# 📊 Generated Files:
#    - Feature importance comparison CSV
#    - Feature importance correlation heatmap
#    - Top features comparison visualization
#    - Individual model explanation plots (SHAP, LIME, etc.)
#    - Comprehensive explainability results pickle file
#    - Ablation study results and visualizations
#    - Analysis log file
#
# 🚀 Ready for business implementation and model deployment!
#
# 🎉 Analysis complete! Results saved to: bike_sharing_section3_explainability.pkl

# %% [markdown]
# ## 5. Results Summary
#
# Display key results and insights from the analysis:

# %%
# Display key results summary
if 'results' in locals() and results is not None:
    print("🎯 ANALYSIS RESULTS SUMMARY")
    print("=" * 50)
    print(f"Models Analyzed: {results['models_analyzed']}")
    print(f"Total Features: {len(results['feature_names'])}")
    
    if results['avg_importance'] is not None:
        print(f"\nTop 5 Most Important Features:")
        for i, (feature, importance) in enumerate(results['avg_importance'].head(5).items()):
            print(f"   {i+1}. {feature}: {importance:.4f}")
    
    print(f"\nResults saved to: {results['results_file']}")
    print("\n📊 Generated visualizations and reports in ./Section3_Explainability/")
    
elif 'explainer' in locals():
    print("🎯 STEP-BY-STEP ANALYSIS COMPLETED")
    print("=" * 50)
    print(f"Models Analyzed: {list(explainer.explanations.keys())}")
    print(f"Total Features: {len(feature_names)}")
    
    if 'avg_importance' in locals() and avg_importance is not None:
        print(f"\nTop 5 Most Important Features:")
        for i, (feature, importance) in enumerate(avg_importance.head(5).items()):
            print(f"   {i+1}. {feature}: {importance:.4f}")
    
    print("\n📊 Generated visualizations and reports in ./Section3_Explainability/")
    
else:
    print("⚠️ No analysis results available. Please run the analysis first.")
# Out:
# 🎯 STEP-BY-STEP ANALYSIS COMPLETED
# ==================================================
# Models Analyzed: ['XGBoost', 'Improved FT-Transformer', 'SAINT']
# Total Features: 13
#
# Top 5 Most Important Features:
#    1. hr: 0.4918
#    2. workingday: 0.1318
#    3. yr: 0.0772
#    4. temp: 0.0688
#    5. instant: 0.0486
#
# 📊 Generated visualizations and reports in ./Section3_Explainability/

# %% [markdown]
# ## 6. Next Steps
#
# After completing this explainability analysis, you can:
#
# 1. **Review Generated Files**: Check the `./Section3_Explainability/` directory for:
#    - Feature importance comparison CSV
#    - SHAP and LIME explanation plots
#    - Ablation study results
#    - Comprehensive analysis logs
#
# 2. **Business Implementation**: Use the business insights to:
#    - Optimize bike distribution strategies
#    - Improve demand forecasting models
#    - Develop weather-based operational plans
#
# 3. **Model Deployment**: Choose the best model based on:
#    - Performance metrics (R², RMSE, MAE)
#    - Interpretability requirements
#    - Computational efficiency needs
#
# 4. **Further Analysis**: Consider:
#    - Time-series specific explainability
#    - Seasonal pattern analysis
#    - Real-time prediction monitoring
