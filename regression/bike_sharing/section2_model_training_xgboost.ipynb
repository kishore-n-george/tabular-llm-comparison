# %% [markdown]
# # Section 2: Model Training and Evaluation
#
# ## Bike Sharing Dataset - XGBoost Regression Model
#
# This notebook trains and evaluates XGBoost regression model on the Bike Sharing Dataset.
#
# **Model Evaluated:**
# - **XGBoost**: Gradient boosting with tree-based learners for regression
#
# **Evaluation Components:**
# - Comprehensive regression performance metrics
# - Actual vs Predicted plots
# - Residual analysis
# - Feature importance analysis
# - Cross-validation evaluation
# - Computational efficiency analysis

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import warnings
import os
warnings.filterwarnings('ignore')

# Import our XGBoost training functions
from xgboost_training_functions import (
    setup_logging,
    load_preprocessed_data,
    initialize_evaluator,
    train_xgboost_model,
    analyze_feature_importance,
    analyze_model_performance,
    perform_cross_validation,
    analyze_predictions_by_range,
    perform_error_analysis,
    generate_business_insights,
    save_results,
    print_final_summary
)

# Set random seeds for reproducibility
np.random.seed(42)

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

print("🚀 Section 2: XGBoost Model Training and Evaluation")
print("Dataset: Bike Sharing Dataset")
print("Task: Regression - Predicting bike rental count")
# Out:
# 🚀 Section 2: XGBoost Model Training and Evaluation
# Dataset: Bike Sharing Dataset
# Task: Regression - Predicting bike rental count

# %% [markdown]
# ## 2.1 Setup Logging and Load Data

# %%
# Setup logging - all print statements will be logged to Section2_Model_Training.log
logger = setup_logging('Section2_Model_Training.log')

# Load preprocessed data from Section 1
data = load_preprocessed_data(logger)

print("✅ Data loaded and logging setup completed!")
# Out:
# 2025-07-27 04:04:19,663 - INFO - 🚀 Section 2: XGBoost Model Training and Evaluation
# 2025-07-27 04:04:19,664 - INFO - Dataset: Bike Sharing Dataset
# 2025-07-27 04:04:19,665 - INFO - Task: Regression - Predicting bike rental count
# 2025-07-27 04:04:19,666 - INFO - ✅ Preprocessed data loaded successfully!
# 2025-07-27 04:04:19,667 - INFO - Training set: (11122, 13)
# 2025-07-27 04:04:19,668 - INFO - Validation set: (2781, 13)
# 2025-07-27 04:04:19,668 - INFO - Test set: (3476, 13)
# 2025-07-27 04:04:19,669 - INFO - Features: 13
# 2025-07-27 04:04:19,669 - INFO - Task: Regression
# 2025-07-27 04:04:19,670 - INFO - Target range: [1, 976]
# ✅ Data loaded and logging setup completed!

# %% [markdown]
# ## 2.2 Initialize Evaluator

# %%
# Initialize comprehensive evaluator
evaluator, models = initialize_evaluator(data, logger)

print("✅ Evaluator initialized successfully!")
# Out:
# 2025-07-27 04:04:23,685 - INFO - 🔧 Evaluator initialized
# 2025-07-27 04:04:23,686 - INFO - Ready to train XGBoost model on 13 features
# 2025-07-27 04:04:23,686 - INFO - Training samples: 11,122
# 2025-07-27 04:04:23,687 - INFO - Test samples: 3,476
# 2025-07-27 04:04:23,687 - INFO - Task: Regression (Bike Count Prediction)
# 2025-07-27 04:04:23,688 - INFO -
# Target distribution:
# 2025-07-27 04:04:23,689 - INFO - Training:   Mean=190.26, Std=182.62, Range=[1, 976]
# 2025-07-27 04:04:23,690 - INFO - Validation: Mean=191.83, Std=180.56, Range=[1, 963]
# 2025-07-27 04:04:23,691 - INFO - Test:       Mean=185.01, Std=177.95, Range=[1, 977]
# ✅ Evaluator initialized successfully!

# %% [markdown]
# ## 2.3 Train XGBoost Model

# %%
# Train XGBoost regression model
xgb_model, xgb_results = train_xgboost_model(data, evaluator, logger)
models['XGBoost'] = xgb_model

print("✅ XGBoost model trained successfully!")
# Out:
# 2025-07-27 04:04:32,746 - INFO - 🌳 Training XGBoost for Regression...
# ==================================================
# Evaluating XGBoost
# ==================================================
#
# 📊 Regression Performance Metrics:
#    R² Score: 0.9546
#    RMSE: 37.9232
#    MAE: 23.8845
#    MSE: 1438.1665
#    MAPE: 0.4525%
#    Explained Variance: 0.9546
#    Max Error: 386.8456
#    Median Absolute Error: 14.8413
#
# ⏱️  Timing:
#    Training Time: 0.4124s
#    Inference Time: 0.0038s
#    Predictions/sec: 914470
#
# 🔄 Cross-Validation:
#    R² Score: 0.9499 ± 0.0031
# 2025-07-27 04:04:36,300 - INFO - ✅ XGBoost training completed
# 2025-07-27 04:04:36,300 - INFO -
# 📊 XGBoost Results:
# 2025-07-27 04:04:36,301 - INFO -    R² Score: 0.9546
# 2025-07-27 04:04:36,302 - INFO -    RMSE: 37.9232
# 2025-07-27 04:04:36,302 - INFO -    MAE: 23.8845
# 2025-07-27 04:04:36,303 - INFO -    MAPE: 0.4525%
# 2025-07-27 04:04:36,304 - INFO -    Explained Variance: 0.9546
# 2025-07-27 04:04:36,304 - INFO -    Training Time: 0.41s
# ✅ XGBoost model trained successfully!

# %% [markdown]
# ## 2.4 Feature Importance Analysis

# %%
# Analyze and plot feature importance
feature_importance_df = analyze_feature_importance(xgb_model, data['feature_names'], logger)

print("✅ Feature importance analysis completed!")
# Out:
# 2025-07-27 04:04:42,943 - INFO -
# 🔍 Feature Importance Analysis
# 2025-07-27 04:04:42,944 - INFO - ==================================================
# 2025-07-27 04:04:42,946 - INFO - Top 10 Most Important Features:
# 2025-07-27 04:04:42,949 - INFO -    feature  importance
# workingday    0.282269
#         hr    0.206195
#         yr    0.172483
#       temp    0.081290
#     season    0.052346
#    instant    0.043647
#      atemp    0.043309
#        hum    0.039911
# weathersit    0.031374
#    weekday    0.015807
# ✅ Feature importance analysis completed!

# %% [markdown]
# ## 2.5 Model Performance Analysis

# %%
# Analyze model performance in detail
y_pred, performance_metrics = analyze_model_performance(xgb_model, data, logger)

print("✅ Model performance analysis completed!")
# Out:
# 2025-07-27 04:04:44,686 - INFO -
# 📈 Model Performance Analysis
# 2025-07-27 04:04:44,687 - INFO - ==================================================
# 2025-07-27 04:04:44,693 - INFO - Detailed Performance Metrics:
# 2025-07-27 04:04:44,694 - INFO -   Mean Squared Error (MSE): 1438.1665
# 2025-07-27 04:04:44,695 - INFO -   Root Mean Squared Error (RMSE): 37.9232
# 2025-07-27 04:04:44,696 - INFO -   Mean Absolute Error (MAE): 23.8845
# 2025-07-27 04:04:44,697 - INFO -   R² Score: 0.9546
# 2025-07-27 04:04:44,697 - INFO -   Mean Absolute Percentage Error (MAPE): 0.4525%
# 2025-07-27 04:04:44,699 - INFO -   Explained Variance Score: 0.9546
# 2025-07-27 04:04:44,699 - INFO -
# 🎯 Performance Interpretation:
# 2025-07-27 04:04:44,700 - INFO -    ✅ Excellent performance (R² = 0.9546)
# 2025-07-27 04:04:44,700 - INFO -    Average prediction error: ±24 bikes
# 2025-07-27 04:04:44,701 - INFO -    Percentage error: 0.5%
# ✅ Model performance analysis completed!

# %% [markdown]
# ## 2.6 Cross-Validation Analysis

# %%
# Perform k-fold cross-validation
cv_scores = perform_cross_validation(xgb_model, data, logger)

print("✅ Cross-validation analysis completed!")
# Out:
# 2025-07-27 04:04:46,943 - INFO -
# 🔄 Cross-Validation Analysis
# 2025-07-27 04:04:46,944 - INFO - ==================================================
# 2025-07-27 04:04:47,681 - INFO - 5-Fold Cross-Validation Results:
# 2025-07-27 04:04:47,682 - INFO -   R² Scores: [0.95134064 0.95813197 0.94964282 0.95086976 0.94301823]
# 2025-07-27 04:04:47,683 - INFO -   Mean R² Score: 0.9506
# 2025-07-27 04:04:47,684 - INFO -   Standard Deviation: 0.0048
# 2025-07-27 04:04:47,685 - INFO -   95% Confidence Interval: [0.9412, 0.9600]
# ✅ Cross-validation analysis completed!

# %% [markdown]
# ## 2.7 Prediction Analysis by Range

# %%
# Analyze prediction accuracy across different target value ranges
analyze_predictions_by_range(data['y_test'], y_pred, logger)

print("✅ Prediction range analysis completed!")
# Out:
# 2025-07-27 04:04:53,934 - INFO -
# 🎯 Prediction Analysis
# 2025-07-27 04:04:53,935 - INFO - ==================================================
# 2025-07-27 04:04:53,936 - INFO - Performance by Target Value Range:
# 2025-07-27 04:04:53,937 - INFO - ------------------------------------------------------------
# 2025-07-27 04:04:53,939 - INFO - Low (0-25%)          | Samples:  880 | R²: -0.806 | MAE: 10.4 | MAPE: 1.3%
# 2025-07-27 04:04:53,941 - INFO - Medium-Low (25-50%)  | Samples:  875 | R²: -0.753 | MAE: 22.0 | MAPE: 0.3%
# 2025-07-27 04:04:53,943 - INFO - Medium-High (50-75%) | Samples:  874 | R²: 0.118 | MAE: 24.9 | MAPE: 0.1%
# 2025-07-27 04:04:53,944 - INFO - High (75-100%)       | Samples:  870 | R²: 0.870 | MAE: 38.2 | MAPE: 0.1%
# ✅ Prediction range analysis completed!

# %% [markdown]
# ## 2.8 Error Analysis

# %%
# Perform detailed error analysis
residuals, abs_residuals = perform_error_analysis(data['y_test'], y_pred, logger)

print("✅ Error analysis completed!")
# Out:
# 2025-07-27 04:04:55,450 - INFO -
# 🔍 Error Analysis
# 2025-07-27 04:04:55,451 - INFO - ==================================================
# 2025-07-27 04:04:55,452 - INFO - Top 10 Worst Predictions:
# 2025-07-27 04:04:55,452 - INFO - Actual | Predicted | Error | Abs Error
# 2025-07-27 04:04:55,453 - INFO - ----------------------------------------
# 2025-07-27 04:04:55,453 - INFO -    116 |       503 |  -387 |       387
# 2025-07-27 04:04:55,454 - INFO -    601 |       221 |   380 |       380
# 2025-07-27 04:04:55,454 - INFO -    425 |       764 |  -339 |       339
# 2025-07-27 04:04:55,456 - INFO -    259 |       537 |  -278 |       278
# 2025-07-27 04:04:55,456 - INFO -    114 |       381 |  -267 |       267
# 2025-07-27 04:04:55,457 - INFO -     93 |       334 |  -241 |       241
# 2025-07-27 04:04:55,457 - INFO -    626 |       403 |   223 |       223
# 2025-07-27 04:04:55,458 - INFO -    209 |       412 |  -203 |       203
# 2025-07-27 04:04:55,459 - INFO -    374 |       577 |  -203 |       203
# 2025-07-27 04:04:55,459 - INFO -    232 |       432 |  -200 |       200
# 2025-07-27 04:04:55,460 - INFO -
# Error Statistics:
# 2025-07-27 04:04:55,460 - INFO -   Mean Absolute Error: 23.88
# 2025-07-27 04:04:55,461 - INFO -   Median Absolute Error: 14.84
# 2025-07-27 04:04:55,462 - INFO -   90th Percentile Error: 54.86
# 2025-07-27 04:04:55,463 - INFO -   95th Percentile Error: 75.72
# 2025-07-27 04:04:55,464 - INFO -   Max Error: 386.85
# ✅ Error analysis completed!

# %% [markdown]
# ## 2.9 Business Insights

# %%
# Generate business insights for bike sharing
generate_business_insights(feature_importance_df, data['feature_names'], logger)

print("✅ Business insights generated!")
# Out:
# 2025-07-27 04:04:56,511 - INFO -
# 💼 Business Insights for Bike Sharing
# 2025-07-27 04:04:56,512 - INFO - ==================================================
# 2025-07-27 04:04:56,513 - INFO - Top 5 Most Important Features for Bike Demand:
# 2025-07-27 04:04:56,513 - INFO -   1. workingday: 0.282
# 2025-07-27 04:04:56,514 - INFO -   2. hr: 0.206
# 2025-07-27 04:04:56,515 - INFO -   3. yr: 0.172
# 2025-07-27 04:04:56,516 - INFO -   4. temp: 0.081
# 2025-07-27 04:04:56,517 - INFO -   5. season: 0.052
# 2025-07-27 04:04:56,519 - INFO -
# 🕐 Hour is very important for bike demand prediction
# 2025-07-27 04:04:56,519 - INFO - 🌡️ Temperature is moderately important for bike demand prediction
# 2025-07-27 04:04:56,520 - INFO - 🌤️ Weather situation is less important for bike demand prediction
# ✅ Business insights generated!

# %% [markdown]
# ## 2.10 Save Results

# %%
# Save all results and models
save_results(xgb_model, xgb_results, feature_importance_df, data['y_test'], y_pred, residuals, abs_residuals, logger)

print("✅ All results saved successfully!")
# Out:
# 2025-07-27 04:04:57,704 - INFO -
# 💾 Saving Results
# 2025-07-27 04:04:57,705 - INFO - ==================================================
# 2025-07-27 04:04:57,708 - INFO - ✅ Model results saved to './Section2_Model_Training/xgboost_evaluation_results.csv'
# 2025-07-27 04:04:57,710 - INFO - ✅ Feature importance saved to './Section2_Model_Training/xgboost_feature_importance.csv'
# 2025-07-27 04:04:57,726 - INFO - ✅ Predictions saved to './Section2_Model_Training/xgboost_predictions.csv'
# 2025-07-27 04:04:57,730 - INFO - ✅ Model saved to './Section2_Model_Training/xgboost_model.pkl'
# ✅ All results saved successfully!

# %% [markdown]
# ## 2.11 Final Summary

# %%
# Print comprehensive final summary
print_final_summary(performance_metrics, cv_scores, feature_importance_df, data, logger)

print("\n🎉 XGBoost training and evaluation completed successfully!")
# Out:
# 2025-07-27 04:04:58,905 - INFO -
# ================================================================================
# 2025-07-27 04:04:58,906 - INFO - XGBOOST TRAINING COMPLETION SUMMARY
# 2025-07-27 04:04:58,907 - INFO - ================================================================================
# 2025-07-27 04:04:58,907 - INFO - ✅ Model Successfully Trained: XGBoost Regressor
# 2025-07-27 04:04:58,908 - INFO -
# 📊 Performance Metrics:
# 2025-07-27 04:04:58,908 - INFO -    R² Score: 0.9546
# 2025-07-27 04:04:58,909 - INFO -    RMSE: 37.9232
# 2025-07-27 04:04:58,910 - INFO -    MAE: 23.8845
# 2025-07-27 04:04:58,910 - INFO -    MAPE: 0.4525%
# 2025-07-27 04:04:58,911 - INFO -
# 🔄 Cross-Validation:
# 2025-07-27 04:04:58,912 - INFO -    Mean R² Score: 0.9506 ± 0.0048
# 2025-07-27 04:04:58,912 - INFO -
# 🎯 Business Impact:
# 2025-07-27 04:04:58,915 - INFO -    Average prediction error: ±24 bikes
# 2025-07-27 04:04:58,915 - INFO -    Model explains 95.5% of demand variance
# 2025-07-27 04:04:58,916 - INFO -    Most important feature: workingday
# 2025-07-27 04:04:58,917 - INFO -
# 🎯 Dataset: Bike Sharing Dataset
# 2025-07-27 04:04:58,917 - INFO - 📊 Task: Regression (Bike Rental Count Prediction)
# 2025-07-27 04:04:58,918 - INFO - 🔢 Features: 13
# 2025-07-27 04:04:58,918 - INFO - 📈 Training Samples: 11,122
# 2025-07-27 04:04:58,919 - INFO - 🧪 Test Samples: 3,476
# 2025-07-27 04:04:58,920 - INFO -
# 🚀 XGBoost model ready for deployment and comparison with other models!
# 2025-07-27 04:04:58,920 - INFO -
# 📁 Generated files:
# 2025-07-27 04:04:58,921 - INFO -    - xgboost_evaluation_results.csv
# 2025-07-27 04:04:58,922 - INFO -    - xgboost_feature_importance.csv
# 2025-07-27 04:04:58,922 - INFO -    - xgboost_predictions.csv
# 2025-07-27 04:04:58,924 - INFO -    - xgboost_model.pkl
# 2025-07-27 04:04:58,924 - INFO -    - XGBoost_feature_importance.png
# 2025-07-27 04:04:58,925 - INFO -    - XGBoost_regression_results.png
# 2025-07-27 04:04:58,925 - INFO -    - XGBoost_residual_analysis.png
# 🎉 XGBoost training and evaluation completed successfully!

# %% [markdown]
# ## 2.12 Model and Results Summary

# %%
# Display final results summary
print("\n" + "="*80)
print("FINAL RESULTS SUMMARY")
print("="*80)

print(f"\n📊 XGBoost Performance:")
print(f"   R² Score: {performance_metrics['r2']:.4f}")
print(f"   RMSE: {performance_metrics['rmse']:.4f}")
print(f"   MAE: {performance_metrics['mae']:.4f}")
print(f"   MAPE: {performance_metrics['mape']:.4f}%")

print(f"\n🔄 Cross-Validation:")
print(f"   Mean R² Score: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")

print(f"\n🎯 Top 3 Most Important Features:")
for i, (_, row) in enumerate(feature_importance_df.head(3).iterrows(), 1):
    print(f"   {i}. {row['feature']}: {row['importance']:.3f}")

print(f"\n📁 Generated Files:")
print(f"   - Section2_Model_Training/xgboost_evaluation_results.csv")
print(f"   - Section2_Model_Training/xgboost_feature_importance.csv")
print(f"   - Section2_Model_Training/xgboost_predictions.csv")
print(f"   - Section2_Model_Training/xgboost_model.pkl")
print(f"   - Section2_Model_Training/XGBoost_feature_importance.png")
print(f"   - Section2_Model_Training/XGBoost_regression_results.png")
print(f"   - Section2_Model_Training/XGBoost_residual_analysis.png")
print(f"   - Section2_Model_Training/Section2_Model_Training.log")

print(f"\n🚀 Model ready for deployment and comparison with other models!")
# Out:
# ================================================================================
# FINAL RESULTS SUMMARY
# ================================================================================
#
# 📊 XGBoost Performance:
#    R² Score: 0.9546
#    RMSE: 37.9232
#    MAE: 23.8845
#    MAPE: 0.4525%
#
# 🔄 Cross-Validation:
#    Mean R² Score: 0.9506 ± 0.0048
#
# 🎯 Top 3 Most Important Features:
#    1. workingday: 0.282
#    2. hr: 0.206
#    3. yr: 0.172
#
# 📁 Generated Files:
#    - Section2_Model_Training/xgboost_evaluation_results.csv
#    - Section2_Model_Training/xgboost_feature_importance.csv
#    - Section2_Model_Training/xgboost_predictions.csv
#    - Section2_Model_Training/xgboost_model.pkl
#    - Section2_Model_Training/XGBoost_feature_importance.png
#    - Section2_Model_Training/XGBoost_regression_results.png
#    - Section2_Model_Training/XGBoost_residual_analysis.png
#    - Section2_Model_Training/Section2_Model_Training.log
#
# 🚀 Model ready for deployment and comparison with other models!

# %% [markdown]
# ## 2.13 Quick Model Test

# %%
# Quick test of the trained model
print("\n🧪 Quick Model Test:")
print("-" * 30)

# Test on a few samples
test_indices = [0, 100, 500, 1000, 2000]
print(f"{'Index':<6} {'Actual':<8} {'Predicted':<10} {'Error':<8}")
print("-" * 35)

for idx in test_indices:
    if idx < len(data['y_test']):
        actual = data['y_test'][idx]
        predicted = y_pred[idx]
        error = abs(actual - predicted)
        print(f"{idx:<6} {actual:<8.0f} {predicted:<10.1f} {error:<8.1f}")

print(f"\n✅ Model is working correctly!")
